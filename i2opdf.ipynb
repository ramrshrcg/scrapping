# %% [markdown]
# # PDF OCR Text Extraction Script
#
# This notebook extracts text from Nepali PDF documents using i2pdf.com's OCR service.
#
# ## Dependencies
# If you want to use clipboard functionality on Linux, you need to install either xclip or xsel:
# ```bash
# sudo apt-get install xclip
# # or
# sudo apt-get install xsel
# ```
#
# However, this script has been modified to work without clipboard access by directly extracting text from the webpage elements.

# %%
import time
import shutil
from selenium import webdriver
from selenium.webdriver.common.by import By
import pyperclip
from module.playsound import play_sound

# %%
driver = webdriver.Firefox()
print("🌐 Step 1: Loading fresh OCR page...")
driver.get('https://www.i2pdf.com/pdf-ocr/nepali')
time.sleep(5)  # Wait for page to load completely
# Out:
# 🌐 Step 1: Loading fresh OCR page...

# %%
#5
pdf='/var/home/ramrshrcg/Downloads/nepali datas folder/Nepali Materials/सामाजिक अध्ययन तथा जीवनोपयोगी शिक्षा: कक्षा ११ .pdf'

# %%
pdf='/var/home/ramrshrcg/Downloads/nepali datas folder/Nepali Materials/नेपाली: कक्षा ७ .pdf'
#4'

# %%
pdf='/var/home/ramrshrcg/Downloads/nepali datas folder/Nepali Materials/नेपाली: कक्षा ९ .pdf'
#3

# %%
#2
pdf='/var/home/ramrshrcg/Downloads/nepali datas folder/Nepali Materials/सामाजिक अध्ययन तथा मानव मूल्य शिक्षा: कक्षा ७ .pdf'

# %%
# STEP 2: Upload the PDF file
print("📄 Step 2: Uploading PDF...")
button_for_pdf_upload = driver.find_element(By.ID, 'upload_file')
button_for_pdf_upload.send_keys(pdf)
print("✓ File uploaded successfully")

# Wait for the upload to complete
print("⏳ Waiting for upload to complete...")
time.sleep(150)  # Increased wait time for upload

# Take a screenshot to see what's on the page
# screenshot_path = "/var/home/ramrshrcg/Desktop/Python/scrapping/page_after_upload.png"
# driver.save_screenshot(screenshot_path)
# print(f"✓ Screenshot saved to {screenshot_path}")

# Detect how many pages are in the document
try:
    # Look for page cards in the document
    page_cards = driver.find_elements(By.CSS_SELECTOR, "div.card[data-id]")
    if page_cards:
        print(f"✓ Detected {len(page_cards)} pages in the document")
    else:
        # Try alternative selectors
        page_cards = driver.find_elements(By.CSS_SELECTOR, "div[id][data-filename*='page-']")
        if page_cards:
            print(f"✓ Detected {len(page_cards)} pages using alternative selector")
        else:
            page_cards = driver.find_elements(By.CSS_SELECTOR, "div.card")
            if page_cards:
                print(f"✓ Detected {len(page_cards)} possible page cards")
            else:
                print("⚠️ Could not detect page cards. This might be a single-page document or the page structure is different.")
except Exception as e:
    print(f"Error detecting pages: {e}")
    
# Print the page source for debugging
print("Current page URL:", driver.current_url)
# Out:
# 📄 Step 2: Uploading PDF...
# ✓ File uploaded successfully
# ⏳ Waiting for upload to complete...
# ✓ Detected 195 pages in the document
# Current page URL: https://www.i2pdf.com/pdf-ocr/nepali
# ✓ Detected 195 pages in the document
# Current page URL: https://www.i2pdf.com/pdf-ocr/nepali

# %%
# STEP 3: Extract text from all pages
def find_and_click_button():
    # List of possible button selectors to try
    button_selectors = [
        # CSS Selectors
        {"type": "css", "selector": ".pdf_ocr.btn.btn-primary.mr-2.glow"},
        {"type": "css", "selector": ".pdf_ocr.btn.btn-primary"},
        {"type": "css", "selector": "button.pdf_ocr"},
        {"type": "css", "selector": ".btn-primary"},
        {"type": "css", "selector": "button.btn-primary"},
        {"type": "css", "selector": ".btn-success"},
        {"type": "css", "selector": "button.btn-success"},
        # XPath Selectors
        {"type": "xpath", "selector": "//button[contains(@class, 'pdf_ocr')]"},
        {"type": "xpath", "selector": "//button[contains(@class, 'btn-primary')]"},
        {"type": "xpath", "selector": "//button[contains(@class, 'btn-success')]"},
        {"type": "xpath", "selector": "//button[contains(., 'Start')]"},
        {"type": "xpath", "selector": "//button[contains(., 'Extract')]"},
        {"type": "xpath", "selector": "//button[contains(., 'OCR')]"},
        {"type": "xpath", "selector": "//button[contains(., 'Process')]"},
        {"type": "xpath", "selector": "//button[contains(., 'Convert')]"},
        {"type": "xpath", "selector": "//a[contains(@class, 'btn-primary')]"},
        {"type": "xpath", "selector": "//a[contains(@class, 'btn-success')]"},
        {"type": "xpath", "selector": "//a[contains(@class, 'btn')]"},
        # Generic button selectors
        {"type": "xpath", "selector": "//button"},
        {"type": "css", "selector": "button"}
    ]
    
    # Try each selector
    for selector in button_selectors:
        try:
            if selector["type"] == "css":
                elements = driver.find_elements(By.CSS_SELECTOR, selector["selector"])
            else:
                elements = driver.find_elements(By.XPATH, selector["selector"])
                
            if not elements:
                continue
                
            print(f"Found {len(elements)} elements with selector: {selector['selector']}")
            
            # Try to find a button related to OCR or extraction
            for element in elements:
                try:
                    element_text = element.text.strip().lower()
                    element_class = element.get_attribute('class')
                    element_id = element.get_attribute('id')
                    
                    print(f"Element text: '{element_text}', class: '{element_class}', id: '{element_id}'")
                    
                    # Check if the button looks like an extract/OCR button
                    is_extract_button = (
                        'ocr' in element_text or 
                        'extract' in element_text or
                        'start' in element_text or
                        'process' in element_text or
                        'convert' in element_text or
                        'ocr' in element_class.lower() or
                        'extract' in element_class.lower() or
                        (element_id and ('ocr' in element_id.lower() or 'extract' in element_id.lower()))
                    )
                    
                    if is_extract_button:
                        print(f"Found likely extract button: '{element_text}'")
                        element.click()
                        print("✓ Button clicked successfully")
                        return True
                except Exception as e:
                    print(f"Error examining element: {e}")
            
            # If we didn't find a specific OCR button, try clicking the first button
            if elements:
                print("No specific OCR button found, trying first button")
                elements[0].click()
                print("✓ First button clicked")
                return True
                
        except Exception as e:
            print(f"Selector {selector['selector']} failed: {e}")
    
    return False

# Function to find and extract text from the current page
def find_and_extract_text():
    # Try to get the text using different selectors
    text_selectors = [
        {"type": "id", "selector": "ocrTextBox"},
        {"type": "css", "selector": "textarea.form-control"},
        {"type": "css", "selector": "textarea"},
        {"type": "xpath", "selector": "//textarea"},
        {"type": "css", "selector": "div.form-control"},
        {"type": "css", "selector": "pre"},
        {"type": "xpath", "selector": "//pre"},
        {"type": "css", "selector": ".text-output"},
        {"type": "css", "selector": ".ocr-output"},
        {"type": "css", "selector": ".output-text"},
        {"type": "xpath", "selector": "//*[contains(@id, 'text')]"},
        {"type": "xpath", "selector": "//*[contains(@id, 'ocr')]"},
        {"type": "xpath", "selector": "//*[contains(@class, 'text')]"},
        {"type": "xpath", "selector": "//*[contains(@class, 'ocr')]"},
        {"type": "xpath", "selector": "//*[contains(@class, 'output')]"}
    ]
    
    for selector in text_selectors:
        try:
            if selector["type"] == "id":
                element = driver.find_element(By.ID, selector["selector"])
            elif selector["type"] == "css":
                element = driver.find_element(By.CSS_SELECTOR, selector["selector"])
            else:
                element = driver.find_element(By.XPATH, selector["selector"])
                
            print(f"Found text element with selector: {selector['selector']}")
            
            # Try different ways to get text from the element
            try:
                text = element.get_attribute('value')
                if text and len(text) > 0:
                    print(f"Got text using get_attribute('value') - Length: {len(text)}")
                    return text
            except:
                pass
                
            try:
                text = element.text
                if text and len(text) > 0:
                    print(f"Got text using .text property - Length: {len(text)}")
                    return text
            except:
                pass
                
            try:
                text = element.get_attribute('innerHTML')
                if text and len(text) > 0:
                    print(f"Got text using get_attribute('innerHTML') - Length: {len(text)}")
                    return text
            except:
                pass
                
        except Exception as e:
            print(f"Selector {selector['selector']} failed: {e}")
    
    # If all direct approaches failed, try JavaScript
    try:
        print("Trying JavaScript approaches...")
        
        # Try to get text from any element that might contain OCR results
        text = driver.execute_script("""
            // Function to check if a string looks like OCR output
            function looksLikeOcrOutput(str) {
                if (!str) return false;
                return str.length > 50;  // At least 50 characters
            }
            
            // Try different sources
            var sources = [
                document.getElementById('ocrTextBox'),
                document.querySelector('textarea'),
                document.querySelector('pre'),
                document.querySelector('div.form-control')
            ];
            
            for (var i = 0; i < sources.length; i++) {
                var el = sources[i];
                if (el) {
                    if (el.value && looksLikeOcrOutput(el.value)) 
                        return el.value;
                    if (el.textContent && looksLikeOcrOutput(el.textContent)) 
                        return el.textContent;
                }
            }
            
            return '';
        """)
        
        if text and len(text) > 0:
            print(f"Got text using JavaScript - Length: {len(text)}")
            return text
    except Exception as e:
        print(f"JavaScript approach failed: {e}")
    
    return None

# Function to select a specific page
def select_page(page_num):
    try:
        # Try to find the page element by card ID or data-id
        selectors = [
            f"div.card[data-id='{page_num}']",
            f"div.card[id='{page_num}']",
            f"div[data-id='{page_num}']",
            f"div[id='{page_num}'][data-filename*='page-']"
        ]
        
        for selector in selectors:
            try:
                page_element = driver.find_element(By.CSS_SELECTOR, selector)
                page_element.click()
                print(f"✓ Selected page {page_num}")
                return True
            except:
                continue
                
        # If direct selection failed, try to find by page label
        try:
            page_element = driver.find_element(By.XPATH, f"//div[contains(@class, 'card')]//h5[text()='{page_num}']/..")
            page_element.click()
            print(f"✓ Selected page {page_num} by label")
            return True
        except:
            pass
            
        # Try JavaScript as a last resort
        selected = driver.execute_script(f"""
            var cards = document.querySelectorAll('div.card, div[data-id], div[data-filename*="page-"]');
            for (var i = 0; i < cards.length; i++) {{
                var card = cards[i];
                if (card.getAttribute('data-id') == '{page_num}' || 
                    card.getAttribute('id') == '{page_num}' ||
                    card.querySelector('h5:contains("{page_num}")')) {{
                    card.click();
                    return true;
                }}
            }}
            return false;
        """)
        
        if selected:
            print(f"✓ Selected page {page_num} using JavaScript")
            return True
            
        print(f"⚠️ Could not find page {page_num}")
        return False
    except Exception as e:
        print(f"Error selecting page {page_num}: {e}")
        return False

# First, analyze all interactive elements for debugging
print("Analyzing page for interactive elements...")
try:
    # Get all buttons, links, and inputs
    elements = driver.find_elements(By.CSS_SELECTOR, "button, a.btn, input[type='button'], input[type='submit']")
    print(f"Found {len(elements)} interactive elements:")
    
    for i, element in enumerate(elements):
        try:
            element_text = element.text.strip() if element.text else "[No text]"
            element_tag = element.tag_name
            element_class = element.get_attribute('class')
            element_id = element.get_attribute('id') or "[No ID]"
            element_type = element.get_attribute('type') or "[No type]"
            
            print(f"Element {i+1}: Tag={element_tag}, Text='{element_text}', ID={element_id}, Class={element_class}, Type={element_type}")
        except:
            print(f"Element {i+1}: [Error retrieving details]")
except Exception as e:
    print(f"Error analyzing elements: {e}")

# Take a screenshot before processing
# screenshot_path = "/var/home/ramrshrcg/Desktop/Python/scrapping/page_before_processing.png"
# driver.save_screenshot(screenshot_path)
# print(f"✓ Screenshot saved to {screenshot_path}")

# Save page source for analysis
source_path = "/var/home/ramrshrcg/Desktop/Python/scrapping/page_source_before_processing.html"
with open(source_path, 'w', encoding='utf-8') as f:
    f.write(driver.page_source)
print(f"✓ Page source saved to {source_path}")

# Find all page cards again to confirm count
try:
    # Try various selectors for page cards
    selectors = [
        "div.card[data-id]",
        "div[data-filename*='page-']",
        "div.card",
        "div[id][data-id]"
    ]
    
    for selector in selectors:
        page_cards = driver.find_elements(By.CSS_SELECTOR, selector)
        if page_cards and len(page_cards) > 0:
            print(f"Found {len(page_cards)} pages using selector: {selector}")
            break
    
    # If no pages found, assume single page
    if not page_cards or len(page_cards) == 0:
        page_cards = [None]  # Dummy entry for single page
        print("Assuming single-page document")
except Exception as e:
    print(f"Error detecting pages: {e}")
    page_cards = [None]  # Default to single page
    print("Defaulting to single-page processing due to error")

# Process each page
all_text = ""
for page_idx, _ in enumerate(page_cards, 1):
    page_num = page_idx  # Pages are usually 1-indexed
    
    print(f"\n==== Processing Page {page_num} ====")
    
    # Skip page selection for single page document
    if len(page_cards) > 1:
        # Select the page
        if not select_page(page_num):
            print(f"⚠️ Skipping page {page_num} due to selection failure")
            continue
        
        # Wait for page selection to take effect
        time.sleep(2)
    
    # Look for and click the extract button
    print(f"Looking for extract button for page {page_num}...")
    button_clicked = find_and_click_button()
    
    if not button_clicked:
        print(f"⚠️ Could not find extract button for page {page_num}")
        
        # Try the manual approach for this page if automatic detection fails
        try:
            print("Trying JavaScript to find and click buttons...")
            buttons_found = driver.execute_script("""
                var buttons = document.querySelectorAll('button, a.btn');
                var count = 0;
                for (var i = 0; i < buttons.length; i++) {
                    var btn = buttons[i];
                    var text = btn.innerText.toLowerCase();
                    if (text.includes('ocr') || text.includes('extract') || 
                        text.includes('start') || text.includes('process')) {
                        btn.click();
                        count++;
                        break;
                    }
                }
                return count;
            """)
            
            if buttons_found > 0:
                print(f"✓ Clicked a button using JavaScript")
                button_clicked = True
            else:
                print("⚠️ No buttons found via JavaScript")
        except Exception as e:
            print(f"JavaScript button approach failed: {e}")
    
    if button_clicked:
        # Wait for OCR processing to complete
        print(f"⏳ Waiting for OCR processing to complete for page {page_num}...")
        time.sleep(60)  # Adjust based on processing time per page
        
        # Take a screenshot after processing
        # screenshot_path = f"/var/home/ramrshrcg/Desktop/Python/scrapping/page_{page_num}_after_processing.png"
        # driver.save_screenshot(screenshot_path)
        # print(f"✓ Screenshot saved to {screenshot_path}")
        
        # Extract text from the current page
        print(f"Extracting text from page {page_num}...")
        page_text = find_and_extract_text()
        
        if page_text:
            print(f"✓ Successfully extracted text from page {page_num} (length: {len(page_text)} characters)")
            
            # Add page header and text to the combined text
            all_text += f"\n\n========== PAGE {page_num} ==========\n\n"
            all_text += page_text
        else:
            print(f"⚠️ Could not extract text from page {page_num}")
    
    # If there are more pages, wait before proceeding to next page
    if page_idx < len(page_cards):
        time.sleep(5)  # Brief pause between pages

# If we extracted any text, save it to a file
if all_text.strip():
    print(f"\n✓ Successfully extracted text from {len(page_cards)} pages (total length: {len(all_text)} characters)")
    
    # Create output filename based on input PDF
    import os
    pdf_filename = os.path.basename(pdf)
    output_filename = os.path.splitext(pdf_filename)[0] + "_extracted.txt"
    output_path = os.path.join('/var/home/ramrshrcg/Desktop/Python/scrapping/Book', output_filename)
    
    # Save the extracted text to a file
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(all_text)
    
    print(f"✓ Extracted text saved to: {output_path}")
    
    # Play a sound to notify completion
    try:
        play_sound()
    except:
        print("Sound notification failed, but text was saved successfully")
else:
    print("⚠️ Could not extract any text from any page")
    print("Trying to save page source as a last resort...")
    
    # Save the page source as a last resort
    source_path = "/var/home/ramrshrcg/Desktop/Python/scrapping/page_source_final.html"
    with open(source_path, 'w', encoding='utf-8') as f:
        f.write(driver.page_source)
    print(f"✓ Final page source saved to {source_path}")
    print("Please examine the screenshots and page source to identify the text element")
# Out:
# Analyzing page for interactive elements...
# Found 13 interactive elements:
# Element 1: Tag=button, Text='[No text]', ID=[No ID], Class=navbar-toggler btn btn-icon btn-sm rounded-circle, Type=button
# Element 2: Tag=button, Text='[No text]', ID=[No ID], Class=btn btn-icon btn-sm btn-ghost-light, Type=button
# Element 3: Tag=button, Text='[No text]', ID=botRgn, Class=btn btn-primary, Type=button
# Element 4: Tag=button, Text='Start', ID=[No ID], Class=pdf_ocr btn  btn-primary  mr-2  glow, Type=button
# Element 5: Tag=a, Text='Options', ID=[No ID], Class=js-hs-unfold-invoker options_btn btn btn-soft-secondary, Type=[No type]
# Element 6: Tag=a, Text='[No text]', ID=[No ID], Class=js-hs-unfold-invoker btn btn-icon btn-xs btn-soft-secondary, Type=[No type]
# Element 7: Tag=button, Text='Nepali', ID=[No ID], Class=btn dropdown-toggle btn-soft-primary border, Type=button
# Element 8: Tag=button, Text='[No text]', ID=[No ID], Class=btn dropdown-toggle btn-soft-white border, Type=button
# Element 9: Tag=button, Text='[No text]', ID=dropdownMenu2, Class=btn btn-danger btn-lg px-10 dropdown-toggle , Type=button
# Element 10: Tag=button, Text='[No text]', ID=dropdownMenu3, Class=btn btn-outline-secondary btn-sm dropdown-toggle , Type=button
# Element 11: Tag=a, Text='[No text]', ID=edit_google_docs, Class=btn btn-outline-secondary btn-sm , Type=[No type]
# Element 12: Tag=button, Text='[No text]', ID=copy, Class=copy_btn btn btn-success btn-sm  mr-1, Type=button
# Element 11: Tag=a, Text='[No text]', ID=edit_google_docs, Class=btn btn-outline-secondary btn-sm , Type=[No type]
# Element 12: Tag=button, Text='[No text]', ID=copy, Class=copy_btn btn btn-success btn-sm  mr-1, Type=button
# Element 13: Tag=button, Text='Start', ID=[No ID], Class=pdf_ocr btn  btn-primary  mr-2  glow, Type=button
# ✓ Page source saved to /var/home/ramrshrcg/Desktop/Python/scrapping/page_source_before_processing.html
# Found 195 pages using selector: div.card[data-id]
#
# ==== Processing Page 1 ====
# Element 13: Tag=button, Text='Start', ID=[No ID], Class=pdf_ocr btn  btn-primary  mr-2  glow, Type=button
# ✓ Page source saved to /var/home/ramrshrcg/Desktop/Python/scrapping/page_source_before_processing.html
# Found 195 pages using selector: div.card[data-id]
#
# ==== Processing Page 1 ====
# ✓ Selected page 1
# ✓ Selected page 1
# Looking for extract button for page 1...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 1...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 1...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 1...
# Extracting text from page 1...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 136
# ✓ Successfully extracted text from page 1 (length: 136 characters)
# Extracting text from page 1...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 136
# ✓ Successfully extracted text from page 1 (length: 136 characters)
#
# ==== Processing Page 2 ====
#
# ==== Processing Page 2 ====
# ✓ Selected page 2
# ✓ Selected page 2
# Looking for extract button for page 2...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 2...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 2...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 2...
# Extracting text from page 2...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 680
# ✓ Successfully extracted text from page 2 (length: 680 characters)
# Extracting text from page 2...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 680
# ✓ Successfully extracted text from page 2 (length: 680 characters)
#
# ==== Processing Page 3 ====
#
# ==== Processing Page 3 ====
# ✓ Selected page 3
# ✓ Selected page 3
# Looking for extract button for page 3...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 3...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 3...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 3...
# Extracting text from page 3...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 3088
# ✓ Successfully extracted text from page 3 (length: 3088 characters)
# Extracting text from page 3...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 3088
# ✓ Successfully extracted text from page 3 (length: 3088 characters)
#
# ==== Processing Page 4 ====
#
# ==== Processing Page 4 ====
# ✓ Selected page 4
# ✓ Selected page 4
# Looking for extract button for page 4...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 4...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 4...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 4...
# Extracting text from page 4...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1073
# ✓ Successfully extracted text from page 4 (length: 1073 characters)
# Extracting text from page 4...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1073
# ✓ Successfully extracted text from page 4 (length: 1073 characters)
#
# ==== Processing Page 5 ====
#
# ==== Processing Page 5 ====
# ✓ Selected page 5
# ✓ Selected page 5
# Looking for extract button for page 5...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 5...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 5...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 5...
# Extracting text from page 5...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1437
# ✓ Successfully extracted text from page 5 (length: 1437 characters)
# Extracting text from page 5...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1437
# ✓ Successfully extracted text from page 5 (length: 1437 characters)
#
# ==== Processing Page 6 ====
#
# ==== Processing Page 6 ====
# ✓ Selected page 6
# ✓ Selected page 6
# Looking for extract button for page 6...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 6...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 6...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 6...
# Extracting text from page 6...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 420
# ✓ Successfully extracted text from page 6 (length: 420 characters)
# Extracting text from page 6...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 420
# ✓ Successfully extracted text from page 6 (length: 420 characters)
#
# ==== Processing Page 7 ====
#
# ==== Processing Page 7 ====
# ✓ Selected page 7
# ✓ Selected page 7
# Looking for extract button for page 7...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 7...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 7...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 7...
# Extracting text from page 7...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1443
# ✓ Successfully extracted text from page 7 (length: 1443 characters)
# Extracting text from page 7...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1443
# ✓ Successfully extracted text from page 7 (length: 1443 characters)
#
# ==== Processing Page 8 ====
#
# ==== Processing Page 8 ====
# ✓ Selected page 8
# ✓ Selected page 8
# Looking for extract button for page 8...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 8...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 8...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 8...
# Extracting text from page 8...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1150
# ✓ Successfully extracted text from page 8 (length: 1150 characters)
# Extracting text from page 8...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1150
# ✓ Successfully extracted text from page 8 (length: 1150 characters)
#
# ==== Processing Page 9 ====
#
# ==== Processing Page 9 ====
# ✓ Selected page 9
# ✓ Selected page 9
# Looking for extract button for page 9...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 9...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 9...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 9...
# Extracting text from page 9...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1056
# ✓ Successfully extracted text from page 9 (length: 1056 characters)
# Extracting text from page 9...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1056
# ✓ Successfully extracted text from page 9 (length: 1056 characters)
#
# ==== Processing Page 10 ====
#
# ==== Processing Page 10 ====
# ✓ Selected page 10
# ✓ Selected page 10
# Looking for extract button for page 10...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 10...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 10...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 10...
# Extracting text from page 10...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1424
# ✓ Successfully extracted text from page 10 (length: 1424 characters)
# Extracting text from page 10...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1424
# ✓ Successfully extracted text from page 10 (length: 1424 characters)
#
# ==== Processing Page 11 ====
#
# ==== Processing Page 11 ====
# ✓ Selected page 11
# ✓ Selected page 11
# Looking for extract button for page 11...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 11...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 11...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 11...
# Extracting text from page 11...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1475
# ✓ Successfully extracted text from page 11 (length: 1475 characters)
# Extracting text from page 11...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1475
# ✓ Successfully extracted text from page 11 (length: 1475 characters)
#
# ==== Processing Page 12 ====
#
# ==== Processing Page 12 ====
# ✓ Selected page 12
# ✓ Selected page 12
# Looking for extract button for page 12...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 12...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 12...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 12...
# Extracting text from page 12...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 958
# ✓ Successfully extracted text from page 12 (length: 958 characters)
# Extracting text from page 12...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 958
# ✓ Successfully extracted text from page 12 (length: 958 characters)
#
# ==== Processing Page 13 ====
# ✓ Selected page 13
#
# ==== Processing Page 13 ====
# ✓ Selected page 13
# Looking for extract button for page 13...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 13...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 13...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 13...
# Extracting text from page 13...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1516
# ✓ Successfully extracted text from page 13 (length: 1516 characters)
# Extracting text from page 13...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1516
# ✓ Successfully extracted text from page 13 (length: 1516 characters)
#
# ==== Processing Page 14 ====
#
# ==== Processing Page 14 ====
# ✓ Selected page 14
# ✓ Selected page 14
# Looking for extract button for page 14...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 14...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 14...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 14...
# Extracting text from page 14...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1877
# ✓ Successfully extracted text from page 14 (length: 1877 characters)
# Extracting text from page 14...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1877
# ✓ Successfully extracted text from page 14 (length: 1877 characters)
#
# ==== Processing Page 15 ====
#
# ==== Processing Page 15 ====
# ✓ Selected page 15
# ✓ Selected page 15
# Looking for extract button for page 15...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 15...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 15...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 15...
# Extracting text from page 15...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1265
# ✓ Successfully extracted text from page 15 (length: 1265 characters)
# Extracting text from page 15...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1265
# ✓ Successfully extracted text from page 15 (length: 1265 characters)
#
# ==== Processing Page 16 ====
#
# ==== Processing Page 16 ====
# ✓ Selected page 16
# ✓ Selected page 16
# Looking for extract button for page 16...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 16...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 16...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 16...
# Extracting text from page 16...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1547
# ✓ Successfully extracted text from page 16 (length: 1547 characters)
# Extracting text from page 16...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1547
# ✓ Successfully extracted text from page 16 (length: 1547 characters)
#
# ==== Processing Page 17 ====
#
# ==== Processing Page 17 ====
# ✓ Selected page 17
# ✓ Selected page 17
# Looking for extract button for page 17...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 17...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 17...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 17...
# Extracting text from page 17...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1324
# ✓ Successfully extracted text from page 17 (length: 1324 characters)
# Extracting text from page 17...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1324
# ✓ Successfully extracted text from page 17 (length: 1324 characters)
#
# ==== Processing Page 18 ====
#
# ==== Processing Page 18 ====
# ✓ Selected page 18
# ✓ Selected page 18
# Looking for extract button for page 18...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 18...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 18...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 18...
# Extracting text from page 18...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1302
# ✓ Successfully extracted text from page 18 (length: 1302 characters)
# Extracting text from page 18...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1302
# ✓ Successfully extracted text from page 18 (length: 1302 characters)
#
# ==== Processing Page 19 ====
#
# ==== Processing Page 19 ====
# ✓ Selected page 19
# ✓ Selected page 19
# Looking for extract button for page 19...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 19...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 19...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 19...
# Extracting text from page 19...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1846
# ✓ Successfully extracted text from page 19 (length: 1846 characters)
# Extracting text from page 19...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1846
# ✓ Successfully extracted text from page 19 (length: 1846 characters)
#
# ==== Processing Page 20 ====
#
# ==== Processing Page 20 ====
# ✓ Selected page 20
# ✓ Selected page 20
# Looking for extract button for page 20...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 20...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 20...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 20...
# Extracting text from page 20...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 528
# ✓ Successfully extracted text from page 20 (length: 528 characters)
# Extracting text from page 20...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 528
# ✓ Successfully extracted text from page 20 (length: 528 characters)
#
# ==== Processing Page 21 ====
#
# ==== Processing Page 21 ====
# ✓ Selected page 21
# ✓ Selected page 21
# Looking for extract button for page 21...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 21...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 21...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 21...
# Extracting text from page 21...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1739
# ✓ Successfully extracted text from page 21 (length: 1739 characters)
# Extracting text from page 21...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1739
# ✓ Successfully extracted text from page 21 (length: 1739 characters)
#
# ==== Processing Page 22 ====
#
# ==== Processing Page 22 ====
# ✓ Selected page 22
# ✓ Selected page 22
# Looking for extract button for page 22...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 22...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 22...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 22...
# Extracting text from page 22...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1664
# ✓ Successfully extracted text from page 22 (length: 1664 characters)
# Extracting text from page 22...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1664
# ✓ Successfully extracted text from page 22 (length: 1664 characters)
#
# ==== Processing Page 23 ====
#
# ==== Processing Page 23 ====
# ✓ Selected page 23
# ✓ Selected page 23
# Looking for extract button for page 23...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 23...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 23...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 23...
# Extracting text from page 23...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1314
# ✓ Successfully extracted text from page 23 (length: 1314 characters)
# Extracting text from page 23...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1314
# ✓ Successfully extracted text from page 23 (length: 1314 characters)
#
# ==== Processing Page 24 ====
#
# ==== Processing Page 24 ====
# ✓ Selected page 24
# ✓ Selected page 24
# Looking for extract button for page 24...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 24...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 24...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 24...
# Extracting text from page 24...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 309
# ✓ Successfully extracted text from page 24 (length: 309 characters)
# Extracting text from page 24...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 309
# ✓ Successfully extracted text from page 24 (length: 309 characters)
#
# ==== Processing Page 25 ====
#
# ==== Processing Page 25 ====
# ✓ Selected page 25
# ✓ Selected page 25
# Looking for extract button for page 25...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 25...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 25...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 25...
# Extracting text from page 25...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1769
# ✓ Successfully extracted text from page 25 (length: 1769 characters)
# Extracting text from page 25...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1769
# ✓ Successfully extracted text from page 25 (length: 1769 characters)
#
# ==== Processing Page 26 ====
#
# ==== Processing Page 26 ====
# ✓ Selected page 26
# ✓ Selected page 26
# Looking for extract button for page 26...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 26...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 26...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 26...
# Extracting text from page 26...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1953
# ✓ Successfully extracted text from page 26 (length: 1953 characters)
# Extracting text from page 26...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1953
# ✓ Successfully extracted text from page 26 (length: 1953 characters)
#
# ==== Processing Page 27 ====
#
# ==== Processing Page 27 ====
# ✓ Selected page 27
# ✓ Selected page 27
# Looking for extract button for page 27...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 27...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 27...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 27...
# Extracting text from page 27...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1253
# ✓ Successfully extracted text from page 27 (length: 1253 characters)
# Extracting text from page 27...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1253
# ✓ Successfully extracted text from page 27 (length: 1253 characters)
#
# ==== Processing Page 28 ====
#
# ==== Processing Page 28 ====
# ✓ Selected page 28
# ✓ Selected page 28
# Looking for extract button for page 28...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 28...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 28...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 28...
# Extracting text from page 28...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 870
# ✓ Successfully extracted text from page 28 (length: 870 characters)
# Extracting text from page 28...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 870
# ✓ Successfully extracted text from page 28 (length: 870 characters)
#
# ==== Processing Page 29 ====
#
# ==== Processing Page 29 ====
# ✓ Selected page 29
# ✓ Selected page 29
# Looking for extract button for page 29...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 29...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 29...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 29...
# Extracting text from page 29...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1685
# ✓ Successfully extracted text from page 29 (length: 1685 characters)
# Extracting text from page 29...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1685
# ✓ Successfully extracted text from page 29 (length: 1685 characters)
#
# ==== Processing Page 30 ====
#
# ==== Processing Page 30 ====
# ✓ Selected page 30
# ✓ Selected page 30
# Looking for extract button for page 30...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 30...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 30...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 30...
# Extracting text from page 30...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1327
# ✓ Successfully extracted text from page 30 (length: 1327 characters)
# Extracting text from page 30...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1327
# ✓ Successfully extracted text from page 30 (length: 1327 characters)
#
# ==== Processing Page 31 ====
#
# ==== Processing Page 31 ====
# ✓ Selected page 31
# ✓ Selected page 31
# Looking for extract button for page 31...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 31...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 31...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 31...
# Extracting text from page 31...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1485
# ✓ Successfully extracted text from page 31 (length: 1485 characters)
# Extracting text from page 31...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1485
# ✓ Successfully extracted text from page 31 (length: 1485 characters)
#
# ==== Processing Page 32 ====
#
# ==== Processing Page 32 ====
# ✓ Selected page 32
# ✓ Selected page 32
# Looking for extract button for page 32...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 32...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 32...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 32...
# Extracting text from page 32...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 930
# ✓ Successfully extracted text from page 32 (length: 930 characters)
# Extracting text from page 32...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 930
# ✓ Successfully extracted text from page 32 (length: 930 characters)
#
# ==== Processing Page 33 ====
#
# ==== Processing Page 33 ====
# ✓ Selected page 33
# ✓ Selected page 33
# Looking for extract button for page 33...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 33...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 33...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 33...
# Extracting text from page 33...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1277
# ✓ Successfully extracted text from page 33 (length: 1277 characters)
# Extracting text from page 33...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1277
# ✓ Successfully extracted text from page 33 (length: 1277 characters)
#
# ==== Processing Page 34 ====
#
# ==== Processing Page 34 ====
# ✓ Selected page 34
# ✓ Selected page 34
# Looking for extract button for page 34...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 34...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 34...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 34...
# Extracting text from page 34...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1152
# ✓ Successfully extracted text from page 34 (length: 1152 characters)
# Extracting text from page 34...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1152
# ✓ Successfully extracted text from page 34 (length: 1152 characters)
#
# ==== Processing Page 35 ====
#
# ==== Processing Page 35 ====
# ✓ Selected page 35
# ✓ Selected page 35
# Looking for extract button for page 35...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 35...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 35...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 35...
# Extracting text from page 35...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1833
# ✓ Successfully extracted text from page 35 (length: 1833 characters)
# Extracting text from page 35...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1833
# ✓ Successfully extracted text from page 35 (length: 1833 characters)
#
# ==== Processing Page 36 ====
#
# ==== Processing Page 36 ====
# ✓ Selected page 36
# ✓ Selected page 36
# Looking for extract button for page 36...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 36...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 36...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 36...
# Extracting text from page 36...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1292
# ✓ Successfully extracted text from page 36 (length: 1292 characters)
# Extracting text from page 36...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1292
# ✓ Successfully extracted text from page 36 (length: 1292 characters)
#
# ==== Processing Page 37 ====
#
# ==== Processing Page 37 ====
# ✓ Selected page 37
# ✓ Selected page 37
# Looking for extract button for page 37...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 37...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 37...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 37...
# Extracting text from page 37...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 690
# ✓ Successfully extracted text from page 37 (length: 690 characters)
# Extracting text from page 37...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 690
# ✓ Successfully extracted text from page 37 (length: 690 characters)
#
# ==== Processing Page 38 ====
#
# ==== Processing Page 38 ====
# ✓ Selected page 38
# ✓ Selected page 38
# Looking for extract button for page 38...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 38...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 38...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 38...
# Extracting text from page 38...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1236
# ✓ Successfully extracted text from page 38 (length: 1236 characters)
# Extracting text from page 38...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1236
# ✓ Successfully extracted text from page 38 (length: 1236 characters)
#
# ==== Processing Page 39 ====
#
# ==== Processing Page 39 ====
# ✓ Selected page 39
# ✓ Selected page 39
# Looking for extract button for page 39...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 39...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 39...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 39...
# Extracting text from page 39...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1592
# ✓ Successfully extracted text from page 39 (length: 1592 characters)
# Extracting text from page 39...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1592
# ✓ Successfully extracted text from page 39 (length: 1592 characters)
#
# ==== Processing Page 40 ====
#
# ==== Processing Page 40 ====
# ✓ Selected page 40
# ✓ Selected page 40
# Looking for extract button for page 40...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 40...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 40...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 40...
# Extracting text from page 40...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1459
# ✓ Successfully extracted text from page 40 (length: 1459 characters)
# Extracting text from page 40...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1459
# ✓ Successfully extracted text from page 40 (length: 1459 characters)
#
# ==== Processing Page 41 ====
#
# ==== Processing Page 41 ====
# ✓ Selected page 41
# ✓ Selected page 41
# Looking for extract button for page 41...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 41...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 41...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 41...
# Extracting text from page 41...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1880
# ✓ Successfully extracted text from page 41 (length: 1880 characters)
# Extracting text from page 41...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1880
# ✓ Successfully extracted text from page 41 (length: 1880 characters)
#
# ==== Processing Page 42 ====
#
# ==== Processing Page 42 ====
# ✓ Selected page 42
# ✓ Selected page 42
# Looking for extract button for page 42...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# ...
# Looking for extract button for page 53...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 53...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 53...
# Extracting text from page 53...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1514
# ✓ Successfully extracted text from page 53 (length: 1514 characters)
# Extracting text from page 53...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1514
# ✓ Successfully extracted text from page 53 (length: 1514 characters)
#
# ==== Processing Page 54 ====
#
# ==== Processing Page 54 ====
# ✓ Selected page 54
# ✓ Selected page 54
# Looking for extract button for page 54...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 54...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 54...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 54...
# Extracting text from page 54...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1813
# ✓ Successfully extracted text from page 54 (length: 1813 characters)
# Extracting text from page 54...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1813
# ✓ Successfully extracted text from page 54 (length: 1813 characters)
#
# ==== Processing Page 55 ====
#
# ==== Processing Page 55 ====
# ✓ Selected page 55
# ✓ Selected page 55
# Looking for extract button for page 55...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 55...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 55...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 55...
# Extracting text from page 55...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 992
# ✓ Successfully extracted text from page 55 (length: 992 characters)
# Extracting text from page 55...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 992
# ✓ Successfully extracted text from page 55 (length: 992 characters)
#
# ==== Processing Page 56 ====
#
# ==== Processing Page 56 ====
# ✓ Selected page 56
# ✓ Selected page 56
# Looking for extract button for page 56...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 56...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 56...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 56...
# Extracting text from page 56...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1736
# ✓ Successfully extracted text from page 56 (length: 1736 characters)
# Extracting text from page 56...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1736
# ✓ Successfully extracted text from page 56 (length: 1736 characters)
#
# ==== Processing Page 57 ====
#
# ==== Processing Page 57 ====
# ✓ Selected page 57
# ✓ Selected page 57
# Looking for extract button for page 57...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 57...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 57...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 57...
# Extracting text from page 57...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1843
# ✓ Successfully extracted text from page 57 (length: 1843 characters)
# Extracting text from page 57...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1843
# ✓ Successfully extracted text from page 57 (length: 1843 characters)
#
# ==== Processing Page 58 ====
#
# ==== Processing Page 58 ====
# ✓ Selected page 58
# ✓ Selected page 58
# Looking for extract button for page 58...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 58...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 58...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 58...
# Extracting text from page 58...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1705
# ✓ Successfully extracted text from page 58 (length: 1705 characters)
# Extracting text from page 58...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1705
# ✓ Successfully extracted text from page 58 (length: 1705 characters)
#
# ==== Processing Page 59 ====
#
# ==== Processing Page 59 ====
# ✓ Selected page 59
# ✓ Selected page 59
# Looking for extract button for page 59...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 59...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 59...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 59...
# Extracting text from page 59...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 420
# ✓ Successfully extracted text from page 59 (length: 420 characters)
# Extracting text from page 59...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 420
# ✓ Successfully extracted text from page 59 (length: 420 characters)
#
# ==== Processing Page 60 ====
#
# ==== Processing Page 60 ====
# ✓ Selected page 60
# ✓ Selected page 60
# Looking for extract button for page 60...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 60...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 60...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 60...
# Extracting text from page 60...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1503
# ✓ Successfully extracted text from page 60 (length: 1503 characters)
# Extracting text from page 60...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1503
# ✓ Successfully extracted text from page 60 (length: 1503 characters)
#
# ==== Processing Page 61 ====
#
# ==== Processing Page 61 ====
# ✓ Selected page 61
# ✓ Selected page 61
# Looking for extract button for page 61...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 61...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 61...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 61...
# Extracting text from page 61...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1510
# ✓ Successfully extracted text from page 61 (length: 1510 characters)
# Extracting text from page 61...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1510
# ✓ Successfully extracted text from page 61 (length: 1510 characters)
#
# ==== Processing Page 62 ====
#
# ==== Processing Page 62 ====
# ✓ Selected page 62
# ✓ Selected page 62
# Looking for extract button for page 62...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 62...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 62...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 62...
# Extracting text from page 62...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1532
# ✓ Successfully extracted text from page 62 (length: 1532 characters)
# Extracting text from page 62...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1532
# ✓ Successfully extracted text from page 62 (length: 1532 characters)
#
# ==== Processing Page 63 ====
#
# ==== Processing Page 63 ====
# ✓ Selected page 63
# ✓ Selected page 63
# Looking for extract button for page 63...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 63...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 63...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 63...
# Extracting text from page 63...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1412
# ✓ Successfully extracted text from page 63 (length: 1412 characters)
# Extracting text from page 63...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1412
# ✓ Successfully extracted text from page 63 (length: 1412 characters)
#
# ==== Processing Page 64 ====
#
# ==== Processing Page 64 ====
# ✓ Selected page 64
# ✓ Selected page 64
# Looking for extract button for page 64...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 64...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 64...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 64...
# Extracting text from page 64...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 466
# ✓ Successfully extracted text from page 64 (length: 466 characters)
# Extracting text from page 64...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 466
# ✓ Successfully extracted text from page 64 (length: 466 characters)
#
# ==== Processing Page 65 ====
#
# ==== Processing Page 65 ====
# ✓ Selected page 65
# ✓ Selected page 65
# Looking for extract button for page 65...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 65...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 65...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 65...
# Extracting text from page 65...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1714
# ✓ Successfully extracted text from page 65 (length: 1714 characters)
# Extracting text from page 65...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 1714
# ✓ Successfully extracted text from page 65 (length: 1714 characters)
#
# ==== Processing Page 66 ====
#
# ==== Processing Page 66 ====
# ✓ Selected page 66
# ✓ Selected page 66
# Looking for extract button for page 66...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 66...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 66...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 66...
# Extracting text from page 66...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 2131
# ✓ Successfully extracted text from page 66 (length: 2131 characters)
# Extracting text from page 66...
# Found text element with selector: ocrTextBox
# Got text using get_attribute('value') - Length: 2131
# ✓ Successfully extracted text from page 66 (length: 2131 characters)
#
# ==== Processing Page 67 ====
#
# ==== Processing Page 67 ====
# ✓ Selected page 67
# ✓ Selected page 67
# Looking for extract button for page 67...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# Looking for extract button for page 67...
# Found 2 elements with selector: .pdf_ocr.btn.btn-primary.mr-2.glow
# Element text: 'start', class: 'pdf_ocr btn  btn-primary  mr-2  glow', id: ''
# Found likely extract button: 'start'
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 67...
# ✓ Button clicked successfully
# ⏳ Waiting for OCR processing to complete for page 67...

# %%
# OPTIONAL: Manual intervention if automatic page processing fails
# Uncomment and run this cell only if the automatic page extraction fails
# This gives you time to manually handle a specific page

"""
# Which page needs manual intervention?
page_num = 1  # Change this to the problematic page number

print(f"⚠️ Manual intervention required for page {page_num}")
print("You have 60 seconds to:")
print("1. Click on the correct page (if needed)")
print("2. Click the 'Start' button")
print("3. Wait for OCR to complete")
print("4. The script will continue automatically after the timeout")

time.sleep(60)  # Wait for manual intervention
print("✓ Continuing with extraction...")

# Take a screenshot after manual intervention
screenshot_path = f"/var/home/ramrshrcg/Desktop/Python/scrapping/page_{page_num}_after_manual.png"
driver.save_screenshot(screenshot_path)
print(f"✓ Screenshot saved to {screenshot_path}")

# Try to extract text from the current page
from selenium.webdriver.common.by import By
import time

# Extract text
extracted_text = None
try:
    # First try by ID
    text_element = driver.find_element(By.ID, 'ocrTextBox')
    extracted_text = text_element.get_attribute('value')
except:
    try:
        # Then try by tag
        text_element = driver.find_element(By.CSS_SELECTOR, 'textarea')
        extracted_text = text_element.get_attribute('value')
    except:
        print("Could not find text element after manual intervention")

if extracted_text:
    print(f"✓ Successfully extracted text (length: {len(extracted_text)} characters)")
    
    # Create output filename for this page
    import os
    pdf_filename = os.path.basename(pdf)
    output_filename = os.path.splitext(pdf_filename)[0] + f"_page{page_num}_manual_extracted.txt"
    output_path = os.path.join('/var/home/ramrshrcg/Desktop/Python/scrapping/Book', output_filename)
    
    # Save the extracted text to a file
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(extracted_text)
    
    print(f"✓ Extracted text saved to: {output_path}")
"""
# Out:
# '\n# Which page needs manual intervention?\npage_num = 1  # Change this to the problematic page number\n\nprint(f"⚠️ Manual intervention required for page {page_num}")\nprint("You have 60 seconds to:")\nprint("1. Click on the correct page (if needed)")\nprint("2. Click the \'Start\' button")\nprint("3. Wait for OCR to complete")\nprint("4. The script will continue automatically after the timeout")\n\ntime.sleep(60)  # Wait for manual intervention\nprint("✓ Continuing with extraction...")\n\n# Take a screenshot after manual intervention\nscreenshot_path = f"/var/home/ramrshrcg/Desktop/Python/scrapping/page_{page_num}_after_manual.png"\ndriver.save_screenshot(screenshot_path)\nprint(f"✓ Screenshot saved to {screenshot_path}")\n\n# Try to extract text from the current page\nfrom selenium.webdriver.common.by import By\nimport time\n\n# Extract text\nextracted_text = None\ntry:\n    # First try by ID\n    text_element = driver.find_element(By.ID, \'ocrTextBox\')\n    extracted_text = text_element.get_attribute(\'value\')\nexcept:\n    try:\n        # Then try by tag\n        text_element = driver.find_element(By.CSS_SELECTOR, \'textarea\')\n        extracted_text = text_element.get_attribute(\'value\')\n    except:\n        print("Could not find text element after manual intervention")\n\nif extracted_text:\n    print(f"✓ Successfully extracted text (length: {len(extracted_text)} characters)")\n\n    # Create output filename for this page\n    import os\n    pdf_filename = os.path.basename(pdf)\n    output_filename = os.path.splitext(pdf_filename)[0] + f"_page{page_num}_manual_extracted.txt"\n    output_path = os.path.join(\'/var/home/ramrshrcg/Desktop/Python/scrapping/Book\', output_filename)\n\n    # Save the extracted text to a file\n    with open(output_path, \'w\', encoding=\'utf-8\') as f:\n        f.write(extracted_text)\n\n    print(f"✓ Extracted text saved to: {output_path}")\n'

# %%
# STEP 4: Optional Additional Text Extraction
# This cell can be used if you need to extract text again from a specific page
# For example, if a previous extraction failed or you need to re-extract


# If you need to extract text from the current state of the page:
extracted_text = None

# Try different methods to get the text
for selector in ['#ocrTextBox', 'textarea', 'pre', '.text-output']:
    try:
        element = driver.find_element(By.CSS_SELECTOR, selector)
        text = element.get_attribute('value') or element.text
        if text and len(text) > 0:
            extracted_text = text
            print(f"Found text using selector: {selector} (length: {len(text)} chars)")
            break
    except:
        pass

# JavaScript fallback
if not extracted_text:
    try:
        extracted_text = driver.execute_script("""
            var textarea = document.querySelector('textarea');
            if (textarea && textarea.value) return textarea.value;
            var pre = document.querySelector('pre');
            if (pre && pre.textContent) return pre.textContent;
            return '';
        """)
        
        if extracted_text:
            print(f"Found text using JavaScript (length: {len(extracted_text)} chars)")
    except:
        pass

# Save the text if found
if extracted_text:
    # Create unique filename
    import os
    import time
    timestamp = int(time.time())
    pdf_filename = os.path.basename(pdf)
    output_filename = os.path.splitext(pdf_filename)[0] + f"_additional_{timestamp}.txt"
    output_path = os.path.join('/var/home/ramrshrcg/Desktop/Python/scrapping/Book', output_filename)
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(extracted_text)
    
    print(f"✓ Additional extracted text saved to: {output_path}")
else:
    print("⚠️ No additional text found")
# Out:
# ⚠️ No additional text found

# %%
# STEP 5: Clean up
driver.close()
print("✓ Browser closed")
print("✅ OCR extraction completed successfully!")
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # STEP 5: Clean up
# ----> 2 driver.close()
#       3 print("✓ Browser closed")
#       4 print("✅ OCR extraction completed successfully!")
#
# File ~/Desktop/Python/scrapping/.venv/lib64/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:595, in WebDriver.close(self)
#     588 def close(self) -> None:
#     589     """Closes the current window.
#     590
#     591     Example:
#     592     --------
#     593     >>> driver.close()
#     594     """
# --> 595     self.execute(Command.CLOSE)
#
# File ~/Desktop/Python/scrapping/.venv/lib64/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:447, in WebDriver.execute(self, driver_command, params)
#     445 response = self.command_executor.execute(driver_command, params)
#     446 if response:
# --> 447     self.error_handler.check_response(response)
#     448     response["value"] = self._unwrap_value(response.get("value", None))
#     449     return response
#
# File ~/Desktop/Python/scrapping/.venv/lib64/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: Tried to run command without establishing a connection

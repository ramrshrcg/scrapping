# %%
import pandas as pd
import csv

def remove_duplicate_titles(input_file, output_file=None, title_column='शीर्षक', description_column='विवरण'):
    """
    Remove duplicate titles from a CSV file, keeping only the first occurrence.
    
    Parameters:
    input_file (str): Path to the input CSV file
    output_file (str): Path to the output CSV file (optional, defaults to input_file with '_cleaned' suffix)
    title_column (str): Name of the title column (default: 'title')
    description_column (str): Name of the description column (default: 'description')
    """
    
    try:
        # Read the CSV file
        df = pd.read_csv(input_file)
        
        # Check if required columns exist
        if title_column not in df.columns:
            print(f"Error: Column '{title_column}' not found in the CSV file.")
            print(f"Available columns: {list(df.columns)}")
            return
        
        if description_column not in df.columns:
            print(f"Error: Column '{description_column}' not found in the CSV file.")
            print(f"Available columns: {list(df.columns)}")
            return
        
        # Display initial statistics
        initial_count = len(df)
        duplicate_count = df[title_column].duplicated().sum()
        
        print(f"Initial number of rows: {initial_count}")
        print(f"Number of duplicate titles found: {duplicate_count}")
        
        # Remove duplicates based on title column, keeping first occurrence
        df_cleaned = df.drop_duplicates(subset=[title_column], keep='first')
        
        # Display final statistics
        final_count = len(df_cleaned)
        removed_count = initial_count - final_count
        
        print(f"Number of rows after cleaning: {final_count}")
        print(f"Number of rows removed: {removed_count}")
        
        # Set output file name if not provided
        if output_file is None:
            output_file = input_file.replace('.csv', '.csv')
        
        # Save the cleaned data
        df_cleaned.to_csv(output_file, index=False)
        print(f"Cleaned data saved to: {output_file}")
        
        # Display some examples of removed duplicates if any
        if duplicate_count > 0:
            print("\nExamples of removed duplicate titles:")
            duplicates = df[df[title_column].duplicated(keep=False)]
            unique_duplicate_titles = duplicates[title_column].unique()[:5]  # Show first 5 duplicate titles
            for title in unique_duplicate_titles:
                print(f"- '{title}'")
        
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
    except pd.errors.EmptyDataError:
        print(f"Error: The file '{input_file}' is empty.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

def remove_duplicate_titles_manual(input_file, output_file=None, title_column_index=0, description_column_index=1):
    """
    Alternative method using manual CSV processing (without pandas)
    
    Parameters:
    input_file (str): Path to the input CSV file
    output_file (str): Path to the output CSV file
    title_column_index (int): Index of the title column (0-based)
    description_column_index (int): Index of the description column (0-based)
    """
    
    try:
        seen_titles = set()
        cleaned_rows = []
        
        with open(input_file, 'r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            header = next(reader)  # Read header
            cleaned_rows.append(header)
            
            initial_count = 0
            for row in reader:
                initial_count += 1
                title = row[title_column_index].strip()
                
                if title not in seen_titles:
                    seen_titles.add(title)
                    cleaned_rows.append(row)
        
        # Set output file name if not provided
        if output_file is None:
            output_file = input_file.replace('.csv', '_cleaned_manual.csv')
        
        # Write cleaned data
        with open(output_file, 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerows(cleaned_rows)
        
        final_count = len(cleaned_rows) - 1  # Subtract header row
        removed_count = initial_count - final_count
        
        print(f"Initial number of rows: {initial_count}")
        print(f"Number of rows after cleaning: {final_count}")
        print(f"Number of rows removed: {removed_count}")
        print(f"Cleaned data saved to: {output_file}")
        
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# # Example usage
# if __name__ == "__main__":
#     # Example 1: Using pandas (recommended)
#     input_csv = 'News_csv/AnnapurnaPost/२०८२/असार २८_annupurna_post.csv'
    
#     # Method 1: Automatic column detection (assumes columns are named 'title' and 'description')
#     remove_duplicate_titles(input_csv)
    
#     # Method 2: Specify custom column names
#     # remove_duplicate_titles(input_csv, title_column='Title', description_column='Description')
    
#     # Method 3: Manual processing without pandas
#     # remove_duplicate_titles_manual(input_csv, title_column_index=0, description_column_index=1)
    
#     # Method 4: Specify custom output file
#     # remove_duplicate_titles(input_csv, output_file="cleaned_output.csv")

# %%
import os

folder_path = 'News_csv/AnnapurnaPost/२०८२'
# Get all CSV files in the specified folder
items= os.listdir(folder_path)
for  csv_file in items:
    remove_duplicate_titles(folder_path + '/' + csv_file)
    # print(f"Processing file: {csv_file}")
# Out:
# Initial number of rows: 119
# Number of duplicate titles found: 52
# Number of rows after cleaning: 67
# Number of rows removed: 52
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ११_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आइएमई ग्रुपको लगानीमा नेपालमै पहिलो फाइबर सिमेन्ट बोर्ड उद्योग सञ्चालनमा'
# - 'माधव नेपाललाई ३५ लाख धरौटीमा छाड्न आदेश'
# - 'पतञ्जली जग्गा हिनामिना प्रकरण : माधव नेपालको थुनछेक बहस सकियो'
# - 'रोशी खोलामा एक व्यक्तिको शव फेला'
# - 'लागुऔषधसहित एक जना पक्राउ'
# Initial number of rows: 104
# Number of duplicate titles found: 47
# Number of rows after cleaning: 57
# Number of rows removed: 47
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'दृष्टिका सञ्चालक श्रेष्ठ र सम्पादक सुब्बालाई जनही २५ हजार धरौटीमा छोड्न आदेश'
# - 'रास्वपा सांसद सुमनाको प्रस्ताव निजी विद्यालयलाई १५ वर्षपछि गैरनाफामूलक बनाऔं'
# - 'रुपन्देही ३ मा मोर्चाका तर्फबाट नागरिक उन्मुक्ति पार्टीको दाबेदारी'
# - 'डोटी पूर्णखोप सुनिश्चितता तथा दिगोपना जिल्ला घोषणा'
# - 'सासू आमाको हत्या गरी फरार भएका अभियुक्त २१ वर्षपछि पक्राउ'
# Initial number of rows: 119
# Number of duplicate titles found: 51
# Number of rows after cleaning: 68
# Number of rows removed: 51
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'एसईई नतिजा : यसपटक पनि विद्यार्थीको कठिन विषय बन्यो गणित'
# - 'एसईईको नतिजामा सुधार, तर प्रधानमन्त्रीको 'टार्गेट' भएन पूरा'
# - 'एसईईमा ६१८१ प्रतिशत ग्रेडेड, २८३२ जीपीए ल्याउने विद्यार्थी धेरै'
# - 'शनिबारदेखि तीनवटा प्रदेशमा भारी वर्षा हुने, बाढीपहिरोको उच्च जोखिम'
# - 'नसाको सुरमा ११ वर्षीया बालिकाको सामूहिक बलात्कारपछि हत्या, ५ जना पक्राउ'
# Initial number of rows: 116
# Number of duplicate titles found: 64
# Number of rows after cleaning: 52
# Number of rows removed: 64
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'राजन र सन्तोषी बने रोड रेसका च्याम्पियन'
# - 'पाकिस्तानमा आत्मघाती बम विस्फोटमा आठ सुरक्षाकर्मीको मृत्यु'
# - 'बैंकिङ कसूर मुद्दाका २ जना फरार प्रतिवादी पक्राउ'
# - 'कर्णेल उजिरसिंहको त्यो पहरेदारी'
# - 'जननेताको जन्मजयन्तीमा पूर्वराष्ट्रपति भण्डारीको भावुक सम्बोधन (पूर्णपाठसहित)'
# Initial number of rows: 118
# Number of duplicate titles found: 57
# Number of rows after cleaning: 61
# Number of rows removed: 57
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'संसद बैठक : चोरको आरोपदेखि निजामती विधेयकसम्म'
# - 'प्रतिनिधिसभाबाट संघीय निजामती सेवा विधेयक पारित'
# - 'मोर्चाले काठमाडौंसहित ६ स्थानमा सभा गर्ने, रुपन्देही ३ मा साझा उम्मेदवार पक्का !'
# - 'बालिकाको हत्या गरेर फरार भएका दम्पती पक्राउ'
# - 'किसानले धान दिवसमा नेतासँग मागे मल'
# Initial number of rows: 98
# Number of duplicate titles found: 39
# Number of rows after cleaning: 59
# Number of rows removed: 39
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'स्नाकोत्तर अध्ययनरत अविवाहित छोरीलाई सुनकोशीमा सम्मान'
# - 'ढुंगानालाई कानुन मन्त्रालयको सचिवमा सरुवा'
# - 'पेट्रोलियम पदार्थको मूल्य बढ्यो'
# - 'बसले किच्दा महिलाको मृत्यु'
# - 'निजामती विधेयक प्रतिनिधिसभामा पेस'
# Initial number of rows: 93
# Number of duplicate titles found: 34
# Number of rows after cleaning: 59
# Number of rows removed: 34
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'किसानहरूलाई कृषि उपकरण तथा बिउ बोका प्रदान'
# - 'सरकारी कार्यालयमा प्रशासनको छड्के, ९७ कर्मचारी अनुपस्थित'
# - 'असार ६ गते प्रधानमन्त्रीसँग प्रश्नोत्तर कार्यक्रम'
# - 'विदुरमा विपद् न्यूनीकरण अभियान'
# - 'प्रधानमन्त्री ओली असार १४ गते स्पेन भ्रमणमा जाने'
# Initial number of rows: 88
# Number of duplicate titles found: 38
# Number of rows after cleaning: 50
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'प्रधानमन्त्री ओली र पूर्वराष्ट्रपति भण्डारीबीच झन्डै डेढ घन्टा बालुवाटारमा सघन छलफल'
# - 'रौतहटमा २ सय बढी कांग्रेसमा प्रवेश'
# - 'ऐनविपरीत हुने काजसरुवा बदर गरिने, इजरायलका प्रभावित नेपालीलाई उद्धार गरिने'
# - 'तादीमा युवक बेपत्ता'
# - 'बुधबार देशका यी स्थानमा हुने छ वर्षा'
# Initial number of rows: 81
# Number of duplicate titles found: 33
# Number of rows after cleaning: 48
# Number of rows removed: 33
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'ट्राभल एडभाइजरी जारी गर्दै परराष्ट्र मन्त्रालयले भन्यो इजरायल र इरानसहित मध्यपूर्वी देशको यात्रा स्थगित गर्नू'
# - 'कांग्रेसएमाले बैठक : संसदको गतिरोध हटाउने विषयमा छलफल'
# - 'कांग्रेसएमालेका शीर्ष नेता बालुवाटारमा'
# - 'वीरगन्जमा अफिमसहित चार जना पक्राउ'
# - 'भिजिट भिसा प्रकरणमा प्रधानमन्त्री कार्यालयको चासो: सात दिनभित्र यात्रुहरूको अभिलेख तयार गर्न निर्देशन'
# Initial number of rows: 93
# Number of duplicate titles found: 33
# Number of rows after cleaning: 60
# Number of rows removed: 33
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'नेपालखबर र बिजमाण्डूले सेबोनका अध्यक्ष श्रेष्ठबारेको समाचार हटाउनु नपर्ने'
# - 'बाली जोगाउन खेतमा लगाइएको करेन्ट लागेर महिलाको मृत्यु'
# - 'शुक्रबार देशका यी स्थानमा हुने छ वर्षा'
# - 'आभूषण व्यवसायीले अल्टिमेटमसहित आन्दोलन फिर्ता लिए'
# - 'महिलालाई जबरजस्ती करणी गरेको आरोपमा युवक पक्राउ'
# Initial number of rows: 140
# Number of duplicate titles found: 60
# Number of rows after cleaning: 80
# Number of rows removed: 60
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'केन्याबाट सात जना नेपाली निष्कासित'
# - 'भारतीय दूतावासको आयोजनामा लुम्बिनीमा मनाइयो अन्तर्राष्ट्रिय योग दिवस'
# - 'कर्णालीमा युवा उद्यमशीलता प्रवर्द्धन सम्मेलन'
# - 'सिन्धुलीमा लागूऔषधसहित दुईजना पक्राउ'
# - 'कालीगण्डकी करिडोर सडकखण्ड अझै खुलेन'
# Initial number of rows: 96
# Number of duplicate titles found: 40
# Number of rows after cleaning: 56
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भारतको काशिपुरमा बन्दी बनाइएका ३५ जना नेपाली युवाको उद्धार'
# - 'विभिन्न देश पठाइदिन्छु भन्दै ठगी गर्ने तीनजना पक्राउ'
# - 'महोत्तरीमा बढे सर्पदंशका घटना'
# - 'माइक्रोबस दुर्घटनाका तीन घाइते चितवन रिफर, ६ डिस्चार्ज'
# - '१० नारीलाई कर्णाली नारी सम्मान'
# Initial number of rows: 80
# Number of duplicate titles found: 25
# Number of rows after cleaning: 55
# Number of rows removed: 25
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मिथेन ग्यास र धौवादी फलामको उत्खननबारेरे प्रधानमन्त्री लिए ब्रिफिङ, छिटो उत्पादनमा लाग्न निर्देशन'
# - 'पत्नीको घाँटी थिचेर हत्या गर्ने युवक पक्राउ'
# - 'पोखरीमा डुबेर बालकको मृत्यु'
# - 'हमासले बन्धक बनाएको भनिएका ८ जनाको शव फेला, विपिनको अवस्था अझै अज्ञात'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गरेको आरोपमा एक जना पक्राउ'
# Initial number of rows: 108
# Number of duplicate titles found: 40
# Number of rows after cleaning: 68
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भिजिट भिसा प्रकरणमा उच्चस्तरीय छानबिन समिति बनाउने सरकारको निर्णय'
# - 'सशस्त्रका दुई डीआइजीको पदावधि थप गर्ने सरकारको निर्णय'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गर्ने एक जना पक्राउ'
# - 'खानेपानी मन्त्रीको स्पेन भ्रमण स्वीकृत'
# - 'सम्पत्ति शुद्धीकरण मुद्दामा गणेश लामालाई सर्वोच्च अदालतले दियो सफाइ'
# Initial number of rows: 113
# Number of duplicate titles found: 46
# Number of rows after cleaning: 67
# Number of rows removed: 46
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सोमबार देशका यी स्थानमा हुने छ वर्षा'
# - 'निष्कासित नेपालीलाई लिएर आयो अमेरिकी जहाज'
# - 'सुनका लागि वृद्धाको हत्या: छोरीले बचाइन्, आमाले मारिन्'
# - 'प्रोस्टेट क्यान्सर न्यूनीकरण अभियान'
# - 'पानी ट्यांकीमा डुबेर बालकको मृत्यु'
# Initial number of rows: 75
# Number of duplicate titles found: 27
# Number of rows after cleaning: 48
# Number of rows removed: 27
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'संसद बैठक बुधबारसम्मका लागि स्थगित'
# - 'रुकुमपूर्वको जंगलमा भरुवा बन्दुक फेला'
# - 'पानीमा डुबेर युवकको मृत्यु'
# - 'मोटरसाइकल दुर्घटनामा घाइते भएका पुरुषको मृत्यु'
# - 'संघीय अस्पतालहरूमा दुई हजार बढी स्वास्थ्य जनशक्ति थप्ने तयारी'
# Initial number of rows: 94
# Number of duplicate titles found: 38
# Number of rows after cleaning: 56
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाबाट निष्कासनमा परेका ३७ जना कागजपत्रविहीन, फर्काइनेहरूको विवरणसहित'
# - 'अत्यधिक गर्मीका कारण जनकपुरधामका विद्यालयमा दुई दिन बिदा'
# - 'सरकारले ल्याएको बजेट चित्तबुझ्दो छैन : देउवा'
# - 'खानेपानीको चरम अभाव भोगेका बासिन्दालाई घरघरमा धारा'
# - 'बुधबार देशका यी स्थानमा हुने छ वर्षा'
# Initial number of rows: 75
# Number of duplicate titles found: 31
# Number of rows after cleaning: 44
# Number of rows removed: 31
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'विपक्षीको अवरोधपछि प्रतिनिधिसभा बैठक बिहीबारसम्मका लागि स्थगित'
# - 'गर्मी बढेपछि वीरगन्जका विद्यालयमा दुई दिन बिदा'
# - 'गर्मी बढेपछि धरानका विद्यालयमा बिदा'
# - 'सूचना तथा प्रसारण विभागका महानिर्देशक प्रदीप परियारविरुद्ध ४ करोडको भ्रष्टाचार मुद्दा'
# - 'लुटपाट गरेको आरोपमा दुई जना पक्राउ'
# Initial number of rows: 89
# Number of duplicate titles found: 31
# Number of rows after cleaning: 58
# Number of rows removed: 31
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'प्रतिनिधिसभा बैठक स्थगित, भोलि १ बजे बस्ने'
# - 'जयगढ बजारका आगलागी पीडितलाई ६३ लाख नगद राहत'
# - 'विद्यालयमा हामी साथी साथी कार्यक्रम'
# - 'नदीजन्य पदार्थ उत्खनन नगर्न रौतहट प्रशासनको पत्र'
# - 'सर्पले टोकेर बालिकाको मृत्यु'
# Initial number of rows: 108
# Number of duplicate titles found: 47
# Number of rows after cleaning: 61
# Number of rows removed: 47
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ३०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मेची पुलबाट तस्करी भएको साढे १२ क्विन्टल चिनी बरामद'
# - '४० लाख ठगी गरेको आरोपमा युवक पक्राउ'
# - 'प्रधानमन्त्रीसँग विश्व बैँकका प्रमुख प्रशासकीय अधिकृतको शिष्टाचार भेट'
# - 'पार्टी कार्यालयमा नक्कली पीडितहरू खडा गराउनेहरूलाई कारबाही गर्ने गृहमन्त्रीको चेतावनी'
# - 'मधेशको आर्थिक सर्वेक्षण : आर्थिक वृद्धिदर ३९९ प्रतिशत रहने अनुमान'
# Initial number of rows: 77
# Number of duplicate titles found: 32
# Number of rows after cleaning: 45
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ३१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'बेलिब्रिज भाँचिदा ६ जना कामदार घाइते, चारको अवस्था गम्भीर'
# - 'भारत सरकारद्वारा नेपाललाई ४० एम्बुलेन्स प्रदान'
# - 'आपराधिक लाभ र विद्युतीय अपराधमा संलग्न दुई जना पक्राउ'
# - 'सर्वोच्चमा नियुक्तिका लागि सिफारिस न्यायाधीशविरुद्ध उजुरी आह्वान गर्ने संसदीय समितिको निर्णय'
# - 'दलाल पुँजीवाद र गणतन्त्र विरोधी शक्तिविरुद्ध लड्नुपर्ने अवस्था आयो : प्रचण्ड'
# Initial number of rows: 94
# Number of duplicate titles found: 38
# Number of rows after cleaning: 56
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भ्रष्टाचार न्यूनीकरण, राजस्व चुहावट नियन्त्रण र सम्पत्ति शुद्धीकरणको विषयमा के भने प्रधानमन्त्री ओलीले ?'
# - 'ललितपुरमा करेन्ट लागेर एक जनाको मृत्यु'
# - 'ट्याक्टरको ठक्करबाट मोटरसाइकल चालकको मृत्यु, एक जना घाइते'
# - 'विनियोजन विधेयक, २०८२ प्रतिनिधि सभाबाट बहुमतले पारित'
# - 'अध्यागमनको निर्णयले अमेरिकाबाट निष्कासित भुटानीको बिचल्ली'
# Initial number of rows: 98
# Number of duplicate titles found: 53
# Number of rows after cleaning: 45
# Number of rows removed: 53
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/2025-06-29_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आज राष्ट्रिय धान दिवस : राष्ट्रपतिले रोपे शीतल निवासमा धान'
# - 'प्रतिनिधिसभा बैठक : आज निजामती विधेयक पारित हुने ()'
# - 'माधव नेपालविरुद्ध झाँक्रीको टिप्पणी : मरेको सिनो काँधमा हालेर हिँड्न सकिँदैन, अध्यक्ष फेरौं'
# - 'बर्तौलालाई प्रस्तावित न्यायाधीश पोखरेलको जवाफ  व्यवसायी घरानाको प्रभावमा परी सिफारिस भएको होइन'
# - 'प्रतिनिधिसभामा कांग्रेस र रास्वपाको सवालजवाफ, एकअर्कोले लगाए चोरको आरोप'
# Initial number of rows: 57
# Number of duplicate titles found: 19
# Number of rows after cleaning: 38
# Number of rows removed: 19
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'राष्ट्रपति रनिङ शिल्ड स्याङ्जाको उपाधि गल्याङलाई'
# - 'विराटनगर घोषणापत्र जारी गर्दै उपप्रमुख एवं उपाध्यक्षको राष्ट्रिय सम्मेलन सम्पन्न'
# - 'अख्तियार प्रयोग हुँदैन, काम गर्ने संस्था हो : प्रधानमन्त्री ओली'
# - 'पहिरोले नेपालचीन सीमाको ७१ नम्बर स्तम्भ पुरियो'
# - 'विद्यालयमा निर्वाचनबाटै क्याप्टेन छनौट'
# Initial number of rows: 97
# Number of duplicate titles found: 36
# Number of rows after cleaning: 61
# Number of rows removed: 36
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मधेस प्रदेशको नीति तथा कार्यक्रम : समेटिए सिँचाइदेखि एआईसम्मका योजना'
# - 'पौडी खेल्ने क्रममा भेरीमा डुबेर दुई बालिकाको मृत्यु, बालक बेपत्ता'
# - 'पतञ्जली जग्गा प्रकरण अव अदालतको विषय बनिसक्यो : झलनाथ खनाल'
# - 'बैंकिङ कसुर मुद्दाका प्रतिवादी पक्राउ'
# - 'बाजुराको बाम्का बजारमा भीषण आगलागी'
# Initial number of rows: 135
# Number of duplicate titles found: 57
# Number of rows after cleaning: 78
# Number of rows removed: 57
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - '१५ हजार अम्रिसोका बिरुवा रोपियो'
# - 'एकीकृत समाजवादीको निष्कर्ष नियतवश मुद्दा चलाइयो, क्लिनचिट लिएर आउँछौं'
# - 'सप्तकोसीमा बेपत्ता भएका २ सशस्त्र प्रहरी अझै भेटिएनन्'
# - 'एमालेविरुद्ध चौतर्फी घेराबन्दी छ : महासचिव पोखरेल'
# - 'तुलसी सहकारीका अध्यक्षलाई ६ वर्ष कैद, ६७ करोड ५९ लाख जरिबाना'
# Initial number of rows: 107
# Number of duplicate titles found: 41
# Number of rows after cleaning: 66
# Number of rows removed: 41
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'युवाहरू जागिर खोज्नेतिर होइन, सिर्जना गर्नेतिर लाग्नुपर्छ : प्रधानमन्त्री'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गर्ने दुई जना पक्राउ'
# - ''आतंकवादको जोखिममा नेपाल, राष्ट्रिय सुरक्षामा रणनीतिक रूपान्तरण आवश्यक''
# - 'पौडी खेल्ने क्रममा एक बालिकाको मृत्यु'
# - 'काभ्रेमा बस दुर्घटना हुँदा एक जनाको मृत्यु, तीन घाइते'
# Initial number of rows: 102
# Number of duplicate titles found: 42
# Number of rows after cleaning: 60
# Number of rows removed: 42
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मधेसमा सक्रियता बढाउँदै चिनियाँ दूतावास'
# - 'नियमित विद्युत् आपूर्ति गर्न माग'
# - 'विश्वमा नयाँ वित्तीय व्यवस्था र सशक्त सहकार्यमा प्रधानमन्त्री ओलीको जोड'
# - 'सिस्ने गाउँपालिका पूर्ण खोप सुनिश्चितता प्राप्त गर्ने जिल्लाको पहिलो स्थानीय तह'
# - 'प्रचण्डजी भ्रमबाट मुक्त हुनुहोस्, यो जनयुद्ध होइन : राजेन्द्र लिङ्देन'
# Initial number of rows: 99
# Number of duplicate titles found: 32
# Number of rows after cleaning: 67
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मिथेन ग्यास र धौवादी फलामको उत्खननबारेरे प्रधानमन्त्री लिए ब्रिफिङ, छिटो उत्पादनमा लाग्न निर्देशन'
# - 'पत्नीको घाँटी थिचेर हत्या गर्ने युवक पक्राउ'
# - 'पोखरीमा डुबेर बालकको मृत्यु'
# - 'हमासले बन्धक बनाएको भनिएका ८ जनाको शव फेला, विपिनको अवस्था अझै अज्ञात'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गरेको आरोपमा एक जना पक्राउ'
# Initial number of rows: 108
# Number of duplicate titles found: 40
# Number of rows after cleaning: 68
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भिजिट भिसा प्रकरणमा उच्चस्तरीय छानबिन समिति बनाउने सरकारको निर्णय'
# - 'सशस्त्रका दुई डीआइजीको पदावधि थप गर्ने सरकारको निर्णय'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गर्ने एक जना पक्राउ'
# - 'खानेपानी मन्त्रीको स्पेन भ्रमण स्वीकृत'
# - 'सम्पत्ति शुद्धीकरण मुद्दामा गणेश लामालाई सर्वोच्च अदालतले दियो सफाइ'
# Initial number of rows: 113
# Number of duplicate titles found: 46
# Number of rows after cleaning: 67
# Number of rows removed: 46
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सोमबार देशका यी स्थानमा हुने छ वर्षा'
# - 'निष्कासित नेपालीलाई लिएर आयो अमेरिकी जहाज'
# - 'सुनका लागि वृद्धाको हत्या: छोरीले बचाइन्, आमाले मारिन्'
# - 'प्रोस्टेट क्यान्सर न्यूनीकरण अभियान'
# - 'पानी ट्यांकीमा डुबेर बालकको मृत्यु'
# Initial number of rows: 75
# Number of duplicate titles found: 27
# Number of rows after cleaning: 48
# Number of rows removed: 27
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'संसद बैठक बुधबारसम्मका लागि स्थगित'
# - 'रुकुमपूर्वको जंगलमा भरुवा बन्दुक फेला'
# - 'पानीमा डुबेर युवकको मृत्यु'
# - 'मोटरसाइकल दुर्घटनामा घाइते भएका पुरुषको मृत्यु'
# - 'संघीय अस्पतालहरूमा दुई हजार बढी स्वास्थ्य जनशक्ति थप्ने तयारी'
# Initial number of rows: 94
# Number of duplicate titles found: 38
# Number of rows after cleaning: 56
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाबाट निष्कासनमा परेका ३७ जना कागजपत्रविहीन, फर्काइनेहरूको विवरणसहित'
# - 'अत्यधिक गर्मीका कारण जनकपुरधामका विद्यालयमा दुई दिन बिदा'
# - 'सरकारले ल्याएको बजेट चित्तबुझ्दो छैन : देउवा'
# - 'खानेपानीको चरम अभाव भोगेका बासिन्दालाई घरघरमा धारा'
# - 'बुधबार देशका यी स्थानमा हुने छ वर्षा'
# Initial number of rows: 75
# Number of duplicate titles found: 31
# Number of rows after cleaning: 44
# Number of rows removed: 31
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'विपक्षीको अवरोधपछि प्रतिनिधिसभा बैठक बिहीबारसम्मका लागि स्थगित'
# - 'गर्मी बढेपछि वीरगन्जका विद्यालयमा दुई दिन बिदा'
# - 'गर्मी बढेपछि धरानका विद्यालयमा बिदा'
# - 'सूचना तथा प्रसारण विभागका महानिर्देशक प्रदीप परियारविरुद्ध ४ करोडको भ्रष्टाचार मुद्दा'
# - 'लुटपाट गरेको आरोपमा दुई जना पक्राउ'
# Initial number of rows: 89
# Number of duplicate titles found: 31
# Number of rows after cleaning: 58
# Number of rows removed: 31
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'प्रतिनिधिसभा बैठक स्थगित, भोलि १ बजे बस्ने'
# - 'जयगढ बजारका आगलागी पीडितलाई ६३ लाख नगद राहत'
# - 'विद्यालयमा हामी साथी साथी कार्यक्रम'
# - 'नदीजन्य पदार्थ उत्खनन नगर्न रौतहट प्रशासनको पत्र'
# - 'सर्पले टोकेर बालिकाको मृत्यु'
# Initial number of rows: 108
# Number of duplicate titles found: 47
# Number of rows after cleaning: 61
# Number of rows removed: 47
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ३०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मेची पुलबाट तस्करी भएको साढे १२ क्विन्टल चिनी बरामद'
# - '४० लाख ठगी गरेको आरोपमा युवक पक्राउ'
# - 'प्रधानमन्त्रीसँग विश्व बैँकका प्रमुख प्रशासकीय अधिकृतको शिष्टाचार भेट'
# - 'पार्टी कार्यालयमा नक्कली पीडितहरू खडा गराउनेहरूलाई कारबाही गर्ने गृहमन्त्रीको चेतावनी'
# - 'मधेशको आर्थिक सर्वेक्षण : आर्थिक वृद्धिदर ३९९ प्रतिशत रहने अनुमान'
# Initial number of rows: 77
# Number of duplicate titles found: 32
# Number of rows after cleaning: 45
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ३१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'बेलिब्रिज भाँचिदा ६ जना कामदार घाइते, चारको अवस्था गम्भीर'
# - 'भारत सरकारद्वारा नेपाललाई ४० एम्बुलेन्स प्रदान'
# - 'आपराधिक लाभ र विद्युतीय अपराधमा संलग्न दुई जना पक्राउ'
# - 'सर्वोच्चमा नियुक्तिका लागि सिफारिस न्यायाधीशविरुद्ध उजुरी आह्वान गर्ने संसदीय समितिको निर्णय'
# - 'दलाल पुँजीवाद र गणतन्त्र विरोधी शक्तिविरुद्ध लड्नुपर्ने अवस्था आयो : प्रचण्ड'
# Initial number of rows: 94
# Number of duplicate titles found: 38
# Number of rows after cleaning: 56
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भ्रष्टाचार न्यूनीकरण, राजस्व चुहावट नियन्त्रण र सम्पत्ति शुद्धीकरणको विषयमा के भने प्रधानमन्त्री ओलीले ?'
# - 'ललितपुरमा करेन्ट लागेर एक जनाको मृत्यु'
# - 'ट्याक्टरको ठक्करबाट मोटरसाइकल चालकको मृत्यु, एक जना घाइते'
# - 'विनियोजन विधेयक, २०८२ प्रतिनिधि सभाबाट बहुमतले पारित'
# - 'अध्यागमनको निर्णयले अमेरिकाबाट निष्कासित भुटानीको बिचल्ली'
# Initial number of rows: 98
# Number of duplicate titles found: 53
# Number of rows after cleaning: 45
# Number of rows removed: 53
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/2025-06-29_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आज राष्ट्रिय धान दिवस : राष्ट्रपतिले रोपे शीतल निवासमा धान'
# - 'प्रतिनिधिसभा बैठक : आज निजामती विधेयक पारित हुने ()'
# - 'माधव नेपालविरुद्ध झाँक्रीको टिप्पणी : मरेको सिनो काँधमा हालेर हिँड्न सकिँदैन, अध्यक्ष फेरौं'
# - 'बर्तौलालाई प्रस्तावित न्यायाधीश पोखरेलको जवाफ  व्यवसायी घरानाको प्रभावमा परी सिफारिस भएको होइन'
# - 'प्रतिनिधिसभामा कांग्रेस र रास्वपाको सवालजवाफ, एकअर्कोले लगाए चोरको आरोप'
# Initial number of rows: 57
# Number of duplicate titles found: 19
# Number of rows after cleaning: 38
# Number of rows removed: 19
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'राष्ट्रपति रनिङ शिल्ड स्याङ्जाको उपाधि गल्याङलाई'
# - 'विराटनगर घोषणापत्र जारी गर्दै उपप्रमुख एवं उपाध्यक्षको राष्ट्रिय सम्मेलन सम्पन्न'
# - 'अख्तियार प्रयोग हुँदैन, काम गर्ने संस्था हो : प्रधानमन्त्री ओली'
# - 'पहिरोले नेपालचीन सीमाको ७१ नम्बर स्तम्भ पुरियो'
# - 'विद्यालयमा निर्वाचनबाटै क्याप्टेन छनौट'
# Initial number of rows: 97
# Number of duplicate titles found: 36
# Number of rows after cleaning: 61
# Number of rows removed: 36
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मधेस प्रदेशको नीति तथा कार्यक्रम : समेटिए सिँचाइदेखि एआईसम्मका योजना'
# - 'पौडी खेल्ने क्रममा भेरीमा डुबेर दुई बालिकाको मृत्यु, बालक बेपत्ता'
# - 'पतञ्जली जग्गा प्रकरण अव अदालतको विषय बनिसक्यो : झलनाथ खनाल'
# - 'बैंकिङ कसुर मुद्दाका प्रतिवादी पक्राउ'
# - 'बाजुराको बाम्का बजारमा भीषण आगलागी'
# Initial number of rows: 135
# Number of duplicate titles found: 57
# Number of rows after cleaning: 78
# Number of rows removed: 57
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - '१५ हजार अम्रिसोका बिरुवा रोपियो'
# - 'एकीकृत समाजवादीको निष्कर्ष नियतवश मुद्दा चलाइयो, क्लिनचिट लिएर आउँछौं'
# - 'सप्तकोसीमा बेपत्ता भएका २ सशस्त्र प्रहरी अझै भेटिएनन्'
# - 'एमालेविरुद्ध चौतर्फी घेराबन्दी छ : महासचिव पोखरेल'
# - 'तुलसी सहकारीका अध्यक्षलाई ६ वर्ष कैद, ६७ करोड ५९ लाख जरिबाना'
# Initial number of rows: 107
# Number of duplicate titles found: 41
# Number of rows after cleaning: 66
# Number of rows removed: 41
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'युवाहरू जागिर खोज्नेतिर होइन, सिर्जना गर्नेतिर लाग्नुपर्छ : प्रधानमन्त्री'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गर्ने दुई जना पक्राउ'
# - ''आतंकवादको जोखिममा नेपाल, राष्ट्रिय सुरक्षामा रणनीतिक रूपान्तरण आवश्यक''
# - 'पौडी खेल्ने क्रममा एक बालिकाको मृत्यु'
# - 'काभ्रेमा बस दुर्घटना हुँदा एक जनाको मृत्यु, तीन घाइते'
# Initial number of rows: 102
# Number of duplicate titles found: 42
# Number of rows after cleaning: 60
# Number of rows removed: 42
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मधेसमा सक्रियता बढाउँदै चिनियाँ दूतावास'
# - 'नियमित विद्युत् आपूर्ति गर्न माग'
# - 'विश्वमा नयाँ वित्तीय व्यवस्था र सशक्त सहकार्यमा प्रधानमन्त्री ओलीको जोड'
# - 'सिस्ने गाउँपालिका पूर्ण खोप सुनिश्चितता प्राप्त गर्ने जिल्लाको पहिलो स्थानीय तह'
# - 'प्रचण्डजी भ्रमबाट मुक्त हुनुहोस्, यो जनयुद्ध होइन : राजेन्द्र लिङ्देन'
# Initial number of rows: 99
# Number of duplicate titles found: 32
# Number of rows after cleaning: 67
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'खानेपानीका आयोजना निर्माणमा ढिलासुस्ती गरे ठेक्का रद्द गर्ने मन्त्री यादवको चेतावनी'
# - 'कमलादीमा हिमानी र हृदयन्द्रले गरे दीप प्रज्वलन (फोटो फिचर)'
# - 'भिजिट भिसा प्रकरणमा गृहमन्त्रीले राजीनामा दिनुपर्ने रास्वपाको अडान कायमै'
# - 'जनकपुरमा दुई दिने थारू अन्तर्राष्ट्रिय सम्मेलन सुरू'
# - 'सिंहदरवारमा मन्त्रिपरिषद् बैठक सुरू'
# Initial number of rows: 97
# Number of duplicate titles found: 39
# Number of rows after cleaning: 58
# Number of rows removed: 39
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'कर्णाली डेभलपमेन्ट बैंकमा साढे २ अर्ब हिनामिना, तत्कालीन प्रमुख कार्यकारी अधिकृत पक्राउ'
# - 'जावलाखेलमा रातो मच्छिन्द्रनाथको भोटो देखाइयो'
# - 'काठमाडौंका तीन क्षेत्रबाहेक सबै स्थानमा निषेधाज्ञा'
# - 'सुत्केरीलाई पोषण सामग्री प्रदान'
# - 'विदुरमा बन्यो खुला व्यायामशाला'
# Initial number of rows: 77
# Number of duplicate titles found: 29
# Number of rows after cleaning: 48
# Number of rows removed: 29
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आइतबार देशका यी स्थानमा हुने छ वर्षा'
# - 'कांग्रेसएमालेको रोग सरुवा हो, उनीहरूसँग सहकार्य हुँदैन : अध्यक्ष प्रचण्ड'
# - 'जनताले लडेर ल्याएको गणतन्त्रबाट पछाडि फर्कन सम्भव छैन : प्रधानमन्त्री ओली'
# - 'राजाका नाममा अवसरवादीहरू सलबलाई रहेका छन् : प्रदेश प्रमुख मिया'
# - 'प्रदेशमा पुरानो सडक अलपत्र, नयाँ शिलान्यासको तयारी'
# Initial number of rows: 97
# Number of duplicate titles found: 38
# Number of rows after cleaning: 59
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मधेस सरकारलाई जनमत सचिवको प्रस्ताव एसईईपछि सैन्य तालिम अनिवार्य गरिनुपर्ने'
# - 'टिपरको ठक्करबाट एक जनाको मृत्यु'
# - 'नारायणहिटी दरवार संग्रहालय क्षेत्रमा निषेधाज्ञा'
# - 'राजावादीले शनिबार दरवार मार्ग क्षेत्रमा प्रदर्शन गर्ने'
# - 'कांग्रेस सरकारमा छ भन्दैमा गलत काममा मौन बस्न हुँदैन : शेखर कोइराला'
# Initial number of rows: 150
# Number of duplicate titles found: 51
# Number of rows after cleaning: 99
# Number of rows removed: 51
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'वरीयता मिचेर सशस्त्रमा एआइजी बढुवा'
# - 'कुकुरको प्रयोग गरेर लागुऔषध ओसारपसार'
# - 'खोलामा डुबेर बालकको मृत्यु'
# - 'अमेरिकी दूतावासको सहयोगमा महिला उद्यमीका लागि एकेडेमी सुरु'
# - 'सगरमाथालाई सफा राख्ने प्रयासलाई निरन्तरता दिनुपर्छ : प्रधानमन्त्री'
# Initial number of rows: 101
# Number of duplicate titles found: 41
# Number of rows after cleaning: 60
# Number of rows removed: 41
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'गृहमन्त्री लेखकले भने मैले पनि त न्याय पाउनुपर्यो, मलाई कसले न्याय दिने?'
# - ''राजनीतिक दलहरूले निर्वाधरूपमा काम गर्नै पाएनन्''
# - 'सीआईबीको डीएसपी हुँ भन्दै ठगी गर्ने एक जना पक्राउ'
# - 'भिजिट भिसा प्रकरणमा मेरो कुनै संलग्नता छैन : गृहमन्त्री लेखक'
# - 'रिहा भए अफताब आलम'
# Initial number of rows: 97
# Number of duplicate titles found: 43
# Number of rows after cleaning: 54
# Number of rows removed: 43
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'नेपालमा यसै साताको अन्त्यसम्ममा मनसुन प्रवेश हुने'
# - 'सिन्धुलीमा बाढीले क्षतिग्रस्त विद्यालय पुनर्निर्माण सुरु'
# - 'असार १५ अघि नै विद्यालय शिक्षा ऐन जारी हुन्छ : शिक्षामन्त्री'
# - '३० वर्षपछि वीरगन्ज सहरको मुख्य नाला सफाई गर्दै महानगर'
# - 'वन अतिक्रमण हटाउँदै वन कार्यालय'
# Initial number of rows: 96
# Number of duplicate titles found: 36
# Number of rows after cleaning: 60
# Number of rows removed: 36
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मंगलबार देशका यी स्थानमा हुने छ वर्षा'
# - 'लाखौं जनता सडकमा आए एकैदिनमा गणतन्त्र समाप्त हुन्छ : राजेन्द्र लिङ्देन'
# - 'न्युरोड क्षेत्रमा आइफोन लुट्ने च्वाँचेको समूह पक्राउ'
# - 'कार्यपालिका बैठक बोलाउन मेयर बालेनलाई अल्टिमेटम'
# - 'मकवानपुरमा बस दुर्घटना हुँदा दुई जनाको मृत्यु'
# Initial number of rows: 104
# Number of duplicate titles found: 47
# Number of rows after cleaning: 57
# Number of rows removed: 47
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ११_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाबाट थप ९ नेपाली निष्कासित'
# - 'दुप्चेश्वरमा एकैदिन झण्डै साँढे दुई लाख भेटी संकलन'
# - 'एमालेले भन्यो विद्यादेवी भण्डारी पूर्वराष्ट्रपतिकै हैसियतमा चीन भ्रमणमा जानुभएको हो'
# - 'पूर्वसभामुख महरा प्रकरणमा जोडिएकी रोशनी शाही बालकोटमा मृत फेला'
# - 'सर्वोच्च अदालतले सच्यायो रवि लामिछानेलाई थुनामा पठाउने आदेशको त्रुटि'
# Initial number of rows: 79
# Number of duplicate titles found: 32
# Number of rows after cleaning: 47
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'दुवै अध्यक्षले आआफ्नो नातेदारलाई जागिर लगाउन खोज्दा परीक्षा नै स्थगित'
# - 'सुनसरीमा गोली चल्यो, गाँजा तस्कर घाइते'
# - 'आइतबार देशका यी स्थानमा हुने छ वर्षा'
# - 'डिपो प्रमुखले जागिरबाट निकालेपछि पीडित कर्मचारी आन्दोलित'
# - 'संवैधानिक निकाय सचिवहरूको रिटायरमेण्ट क्लब बन्यो, कुलिङ पिरियड आवश्यक छ : शेखर कोइराला'
# Initial number of rows: 105
# Number of duplicate titles found: 40
# Number of rows after cleaning: 65
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'रवि लामिछानेलाई थुनामुक्त गर्न सर्वोच्चद्वारा अस्वीकार'
# - 'सिंहदरबार गाउँ पुग्यो, अधिकार अझै व्यवहारिक हुन सकेन'
# - 'सवारी चालक अनुमति पत्र सुरक्षण मुद्रण केन्द्रले छाप्ने'
# - 'सिन्धुलीको मुर्की र थाँक्रेगाउँका घर घरमा धारा'
# - '१०८ जनालाई प्रतिवादी बनाउँदै प्रहरीले बुझायो तीनकुने घटनाको प्रतिवेदन'
# Initial number of rows: 90
# Number of duplicate titles found: 35
# Number of rows after cleaning: 55
# Number of rows removed: 35
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भर्जिनियाको दुवै सदनबाट पारित भई सम्मानित हुने पहिलो नेपाली मूलका व्यक्ति बने प्रदीप'
# - 'एक वर्षमा चार कार्यालय प्रमुख'
# - 'हनी ट्र्यापमा पारेर सरकारी कर्मचारीसँग 'घर र जग्गा'को बार्गेनिङ'
# - 'चट्याङ लागेर एक महिलाको मृत्यु'
# - 'विदुर पूर्ण खोप सुनिश्चित नगर घोषित'
# Initial number of rows: 87
# Number of duplicate titles found: 31
# Number of rows after cleaning: 56
# Number of rows removed: 31
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सन्धखर्क नगरपालिका पूर्ण खोप सुनिश्चितता र दिगोपना घोषणा'
# - 'पोखरा विमानस्थल भ्रष्टाचार प्रकरणबारे अनुसन्धान गर्न अख्तियारलाई लेखा समितिको निर्देशन'
# - 'गाउँपालिकाका प्रमुख प्रशासकीय अधिकृत,लेखापालसहित चारजनाविरुद्ध भ्रष्टाचार'
# - 'हिजो समातिएका पालिका अध्यक्ष आज छुटे'
# - 'त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलस्थित अध्यागमन कार्यालयमा अख्तियारको छापा'
# Initial number of rows: 100
# Number of duplicate titles found: 40
# Number of rows after cleaning: 60
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'दुईवटा मोटरसाइकल ठोकिँदा दुवै चालकको मृत्यु'
# - 'साँगाबाट स्रोत नखुलेको २५ लाख सहित दुई युवक पक्राउ'
# - 'राष्ट्र बैंकको गभर्नरमा डा विश्व पौडेल नियुक्त'
# - 'विश्व पौडेलविरुद्धको रिट दरपीठ आदेश सदर'
# - 'करेन्ट लागेर पुजारीको मृत्यु'
# Initial number of rows: 112
# Number of duplicate titles found: 46
# Number of rows after cleaning: 66
# Number of rows removed: 46
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'एउटै परिवारका ६ जनाले गरे एकैपटक मकालु हिमाल आरोहण'
# - 'सबै तहको सरकारमा सहभागी भएर पनि कांग्रेसभित्र असन्तुष्टि छ : महामन्त्री थापा'
# - 'सुर्ती नियन्त्रणमा योगदानका पुर्याएको भन्दै विश्व स्वास्थ्य संगठनद्वारा नेपाल पुरस्कृत'
# - 'पृथ्वी संग्रहालय तोडफोड'
# - 'महोत्तरीमा ८ लाख रुपैयाँ बरामद, २ जना पक्राउ'
# Initial number of rows: 104
# Number of duplicate titles found: 37
# Number of rows after cleaning: 67
# Number of rows removed: 37
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'खानेपानीका आयोजना निर्माणमा ढिलासुस्ती गरे ठेक्का रद्द गर्ने मन्त्री यादवको चेतावनी'
# - 'कमलादीमा हिमानी र हृदयन्द्रले गरे दीप प्रज्वलन (फोटो फिचर)'
# - 'भिजिट भिसा प्रकरणमा गृहमन्त्रीले राजीनामा दिनुपर्ने रास्वपाको अडान कायमै'
# - 'जनकपुरमा दुई दिने थारू अन्तर्राष्ट्रिय सम्मेलन सुरू'
# - 'सिंहदरवारमा मन्त्रिपरिषद् बैठक सुरू'
# Initial number of rows: 97
# Number of duplicate titles found: 39
# Number of rows after cleaning: 58
# Number of rows removed: 39
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'कर्णाली डेभलपमेन्ट बैंकमा साढे २ अर्ब हिनामिना, तत्कालीन प्रमुख कार्यकारी अधिकृत पक्राउ'
# - 'जावलाखेलमा रातो मच्छिन्द्रनाथको भोटो देखाइयो'
# - 'काठमाडौंका तीन क्षेत्रबाहेक सबै स्थानमा निषेधाज्ञा'
# - 'सुत्केरीलाई पोषण सामग्री प्रदान'
# - 'विदुरमा बन्यो खुला व्यायामशाला'
# Initial number of rows: 77
# Number of duplicate titles found: 29
# Number of rows after cleaning: 48
# Number of rows removed: 29
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आइतबार देशका यी स्थानमा हुने छ वर्षा'
# - 'कांग्रेसएमालेको रोग सरुवा हो, उनीहरूसँग सहकार्य हुँदैन : अध्यक्ष प्रचण्ड'
# - 'जनताले लडेर ल्याएको गणतन्त्रबाट पछाडि फर्कन सम्भव छैन : प्रधानमन्त्री ओली'
# - 'राजाका नाममा अवसरवादीहरू सलबलाई रहेका छन् : प्रदेश प्रमुख मिया'
# - 'प्रदेशमा पुरानो सडक अलपत्र, नयाँ शिलान्यासको तयारी'
# Initial number of rows: 97
# Number of duplicate titles found: 38
# Number of rows after cleaning: 59
# Number of rows removed: 38
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मधेस सरकारलाई जनमत सचिवको प्रस्ताव एसईईपछि सैन्य तालिम अनिवार्य गरिनुपर्ने'
# - 'टिपरको ठक्करबाट एक जनाको मृत्यु'
# - 'नारायणहिटी दरवार संग्रहालय क्षेत्रमा निषेधाज्ञा'
# - 'राजावादीले शनिबार दरवार मार्ग क्षेत्रमा प्रदर्शन गर्ने'
# - 'कांग्रेस सरकारमा छ भन्दैमा गलत काममा मौन बस्न हुँदैन : शेखर कोइराला'
# Initial number of rows: 150
# Number of duplicate titles found: 51
# Number of rows after cleaning: 99
# Number of rows removed: 51
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'वरीयता मिचेर सशस्त्रमा एआइजी बढुवा'
# - 'कुकुरको प्रयोग गरेर लागुऔषध ओसारपसार'
# - 'खोलामा डुबेर बालकको मृत्यु'
# - 'अमेरिकी दूतावासको सहयोगमा महिला उद्यमीका लागि एकेडेमी सुरु'
# - 'सगरमाथालाई सफा राख्ने प्रयासलाई निरन्तरता दिनुपर्छ : प्रधानमन्त्री'
# Initial number of rows: 101
# Number of duplicate titles found: 41
# Number of rows after cleaning: 60
# Number of rows removed: 41
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'गृहमन्त्री लेखकले भने मैले पनि त न्याय पाउनुपर्यो, मलाई कसले न्याय दिने?'
# - ''राजनीतिक दलहरूले निर्वाधरूपमा काम गर्नै पाएनन्''
# - 'सीआईबीको डीएसपी हुँ भन्दै ठगी गर्ने एक जना पक्राउ'
# - 'भिजिट भिसा प्रकरणमा मेरो कुनै संलग्नता छैन : गृहमन्त्री लेखक'
# - 'रिहा भए अफताब आलम'
# Initial number of rows: 97
# Number of duplicate titles found: 43
# Number of rows after cleaning: 54
# Number of rows removed: 43
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'नेपालमा यसै साताको अन्त्यसम्ममा मनसुन प्रवेश हुने'
# - 'सिन्धुलीमा बाढीले क्षतिग्रस्त विद्यालय पुनर्निर्माण सुरु'
# - 'असार १५ अघि नै विद्यालय शिक्षा ऐन जारी हुन्छ : शिक्षामन्त्री'
# - '३० वर्षपछि वीरगन्ज सहरको मुख्य नाला सफाई गर्दै महानगर'
# - 'वन अतिक्रमण हटाउँदै वन कार्यालय'
# Initial number of rows: 96
# Number of duplicate titles found: 36
# Number of rows after cleaning: 60
# Number of rows removed: 36
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मंगलबार देशका यी स्थानमा हुने छ वर्षा'
# - 'लाखौं जनता सडकमा आए एकैदिनमा गणतन्त्र समाप्त हुन्छ : राजेन्द्र लिङ्देन'
# - 'न्युरोड क्षेत्रमा आइफोन लुट्ने च्वाँचेको समूह पक्राउ'
# - 'कार्यपालिका बैठक बोलाउन मेयर बालेनलाई अल्टिमेटम'
# - 'मकवानपुरमा बस दुर्घटना हुँदा दुई जनाको मृत्यु'
# Initial number of rows: 104
# Number of duplicate titles found: 47
# Number of rows after cleaning: 57
# Number of rows removed: 47
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ११_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाबाट थप ९ नेपाली निष्कासित'
# - 'दुप्चेश्वरमा एकैदिन झण्डै साँढे दुई लाख भेटी संकलन'
# - 'एमालेले भन्यो विद्यादेवी भण्डारी पूर्वराष्ट्रपतिकै हैसियतमा चीन भ्रमणमा जानुभएको हो'
# - 'पूर्वसभामुख महरा प्रकरणमा जोडिएकी रोशनी शाही बालकोटमा मृत फेला'
# - 'सर्वोच्च अदालतले सच्यायो रवि लामिछानेलाई थुनामा पठाउने आदेशको त्रुटि'
# Initial number of rows: 79
# Number of duplicate titles found: 32
# Number of rows after cleaning: 47
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'दुवै अध्यक्षले आआफ्नो नातेदारलाई जागिर लगाउन खोज्दा परीक्षा नै स्थगित'
# - 'सुनसरीमा गोली चल्यो, गाँजा तस्कर घाइते'
# - 'आइतबार देशका यी स्थानमा हुने छ वर्षा'
# - 'डिपो प्रमुखले जागिरबाट निकालेपछि पीडित कर्मचारी आन्दोलित'
# - 'संवैधानिक निकाय सचिवहरूको रिटायरमेण्ट क्लब बन्यो, कुलिङ पिरियड आवश्यक छ : शेखर कोइराला'
# Initial number of rows: 105
# Number of duplicate titles found: 40
# Number of rows after cleaning: 65
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'रवि लामिछानेलाई थुनामुक्त गर्न सर्वोच्चद्वारा अस्वीकार'
# - 'सिंहदरबार गाउँ पुग्यो, अधिकार अझै व्यवहारिक हुन सकेन'
# - 'सवारी चालक अनुमति पत्र सुरक्षण मुद्रण केन्द्रले छाप्ने'
# - 'सिन्धुलीको मुर्की र थाँक्रेगाउँका घर घरमा धारा'
# - '१०८ जनालाई प्रतिवादी बनाउँदै प्रहरीले बुझायो तीनकुने घटनाको प्रतिवेदन'
# Initial number of rows: 90
# Number of duplicate titles found: 35
# Number of rows after cleaning: 55
# Number of rows removed: 35
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भर्जिनियाको दुवै सदनबाट पारित भई सम्मानित हुने पहिलो नेपाली मूलका व्यक्ति बने प्रदीप'
# - 'एक वर्षमा चार कार्यालय प्रमुख'
# - 'हनी ट्र्यापमा पारेर सरकारी कर्मचारीसँग 'घर र जग्गा'को बार्गेनिङ'
# - 'चट्याङ लागेर एक महिलाको मृत्यु'
# - 'विदुर पूर्ण खोप सुनिश्चित नगर घोषित'
# Initial number of rows: 87
# Number of duplicate titles found: 31
# Number of rows after cleaning: 56
# Number of rows removed: 31
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सन्धखर्क नगरपालिका पूर्ण खोप सुनिश्चितता र दिगोपना घोषणा'
# - 'पोखरा विमानस्थल भ्रष्टाचार प्रकरणबारे अनुसन्धान गर्न अख्तियारलाई लेखा समितिको निर्देशन'
# - 'गाउँपालिकाका प्रमुख प्रशासकीय अधिकृत,लेखापालसहित चारजनाविरुद्ध भ्रष्टाचार'
# - 'हिजो समातिएका पालिका अध्यक्ष आज छुटे'
# - 'त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलस्थित अध्यागमन कार्यालयमा अख्तियारको छापा'
# Initial number of rows: 100
# Number of duplicate titles found: 40
# Number of rows after cleaning: 60
# Number of rows removed: 40
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'दुईवटा मोटरसाइकल ठोकिँदा दुवै चालकको मृत्यु'
# - 'साँगाबाट स्रोत नखुलेको २५ लाख सहित दुई युवक पक्राउ'
# - 'राष्ट्र बैंकको गभर्नरमा डा विश्व पौडेल नियुक्त'
# - 'विश्व पौडेलविरुद्धको रिट दरपीठ आदेश सदर'
# - 'करेन्ट लागेर पुजारीको मृत्यु'
# Initial number of rows: 112
# Number of duplicate titles found: 46
# Number of rows after cleaning: 66
# Number of rows removed: 46
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'एउटै परिवारका ६ जनाले गरे एकैपटक मकालु हिमाल आरोहण'
# - 'सबै तहको सरकारमा सहभागी भएर पनि कांग्रेसभित्र असन्तुष्टि छ : महामन्त्री थापा'
# - 'सुर्ती नियन्त्रणमा योगदानका पुर्याएको भन्दै विश्व स्वास्थ्य संगठनद्वारा नेपाल पुरस्कृत'
# - 'पृथ्वी संग्रहालय तोडफोड'
# - 'महोत्तरीमा ८ लाख रुपैयाँ बरामद, २ जना पक्राउ'
# Initial number of rows: 104
# Number of duplicate titles found: 37
# Number of rows after cleaning: 67
# Number of rows removed: 37
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'रुकुमपूर्वलाई हिमालय टुरिस्ट हब घोषणा'
# - 'बालेनले दिएको जिम्मेवारीमा बस्न तीन वडाध्यक्षद्वारा अस्वीकार'
# - '२० लाख रुपैयाँ बढी हुन्डीको रकमसहित युवक पक्राउ'
# - 'दक्षिण कोरियाले गर्यो १० नेपालीलाई निष्कासन'
# - 'सोमबार देशका यी स्थानमा हुने छ वर्षा'
# Initial number of rows: 92
# Number of duplicate titles found: 36
# Number of rows after cleaning: 56
# Number of rows removed: 36
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'प्रधानमन्त्री ओलीसँग जापानका उपविदेशमन्त्रीको शिष्टाचार भेट'
# - 'सवल शिक्षा'
# - 'कर्णालीको बुटी नै जडी'
# - 'यात्रुसँग मनपरी भाडा लिएको गुनासो आएपछि अनुगमन सुरु'
# - 'प्रधानमन्त्री ओली र कोप२९ का अध्यक्षबीच शिष्टाचार भेट, हिमालदेखि समुद्रसम्मको अवधारणामा छलफल'
# Initial number of rows: 111
# Number of duplicate titles found: 46
# Number of rows after cleaning: 65
# Number of rows removed: 46
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'स्वास्थ्य केन्द्रको भवन उद्घाटन'
# - 'सडक निर्माणका लागि घर भत्काउँदै गाउँपालिका'
# - 'विपद् न्यूनीकरण गर्न प्रहरीलाई तालिम'
# - 'मालिका पिस पार्क र मन्दिरको बारम्बार उद्घाटन'
# - 'भारतीय मन्त्री यादवले 'सगरमाथा संवाद'मा के भने?'
# Initial number of rows: 107
# Number of duplicate titles found: 42
# Number of rows after cleaning: 65
# Number of rows removed: 42
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ १_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'मानसिक स्वास्थ्य समस्या सम्बोधन गर्न जनशक्ति थप्ने तयारी'
# - 'स्वास्थ्य संस्था सञ्चालन मापदण्ड परिमार्जन गर्न समिति गठन'
# - 'सगरमाथा संवादका लागि काठमाडौं आइपुगे भारतीय मन्त्री यादव'
# - 'सुनकोशीस्थित फोक्सिङटारको बेलिबृज हटाइने'
# - 'पर्यटनमार्फत विकास आवश्यक : कांग्रेस प्रवक्ता महत'
# Initial number of rows: 102
# Number of duplicate titles found: 37
# Number of rows after cleaning: 65
# Number of rows removed: 37
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख ३१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'गभर्नर सिफारिस समिति पुनर्गठन, अर्थविद् पाण्डेलाई सदस्य बनाउने निर्णय'
# - 'सत्य निरुपण र बेपत्ता आयोगका पदाधिकारीहरू नियुक्त, थापा र गड्तौलालाई अध्यक्षको जिम्मेवारी'
# - 'विद्युत् प्राधिकरणको मुनाफा यथार्थपरक छैन : महालेखाको प्रतिवेदन'
# - 'पोखरामा माइक्रो दुर्घटना, तीन जनाको मृत्यु'
# - 'खेतबाटै १०६ बोरा गहुँ र २८ बोरा चामलको कनिका बरामद'
# Initial number of rows: 102
# Number of duplicate titles found: 41
# Number of rows after cleaning: 61
# Number of rows removed: 41
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख ३०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाले थप ७ नेपालीलाई गर्यो निष्कासन'
# - '२० बुँदे घोषणा पत्र जारी गर्दै सकियो लोमानथाङ अन्तर्राष्ट्रिय मिडिया समिट'
# - 'आध्यात्मिक ज्ञानमार्फत सद्मार्गमा पुगिन्छ : मुख्यमन्त्री आचार्य'
# - 'त्रिशूली नदीमा दुई किशोरी बेपत्ता'
# - 'सिन्धुलीमा कारको ठक्करबाट बालकको मृत्यु'
# Initial number of rows: 96
# Number of duplicate titles found: 37
# Number of rows after cleaning: 59
# Number of rows removed: 37
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'हुण्डी कारोबारमा संलग्न दुई जना पक्राउ'
# - 'कुलो तर्ने क्रममा युवती बेपत्ता'
# - 'बिहेमा खाजा खाँदा जन्तीसहित एक सय बढी बिरामी'
# - 'रुकुमपश्चिम दुर्घटनामा थप एक जनाको मृत्यु'
# - 'रुकुम पश्चिममा जिप दुर्घटना हुँदा एकको मृत्यु, तीन जना घाइते'
# Initial number of rows: 111
# Number of duplicate titles found: 43
# Number of rows after cleaning: 68
# Number of rows removed: 43
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'खोलामा डुबेर किशोरको मृत्यु'
# - 'गभर्नर सिफारिस समितिबाट विश्व पौडेलले दिए राजीनामा'
# - 'वीरगन्जमा विवाहित महिलामाथि सामूहिक बलात्कार, एकजना पक्राउ'
# - 'बिमितको १८ लाख हिनामिना गर्ने पक्राउ'
# - 'दक्षिण कोरियाले एकैपटक ९ नेपालीलाई गर्यो निष्कासन'
# Initial number of rows: 82
# Number of duplicate titles found: 28
# Number of rows after cleaning: 54
# Number of rows removed: 28
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'बाजुरामा कुपोषणबाट २ महिने शिशुको मृत्यु, दर्जनौं बालबालिका जोखिममा'
# - 'एमाले तादीको अध्यक्षमा मैनाली निर्वाचित'
# - 'बुढीगंगामा दीर्घकालीन समृद्धिको साझा एजेन्डा तय गर्न कचहरी कार्यक्रम'
# - 'मोटरसाइकल दुर्घटनामा दाजुभाइको मृत्यु'
# - 'संग्रहालयको सञ्चालन तथा संरक्षणको कार्य'
# Initial number of rows: 122
# Number of duplicate titles found: 44
# Number of rows after cleaning: 78
# Number of rows removed: 44
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भारतीय दूतावासले भन्यो भारतले पाकिस्तान र त्यहाँका जनतामाथि आक्रमण गरेको होइन, भारतको आक्रमण आतंकवाद र उनीहरूको सेल्टरमाथि हो'
# - 'सिन्धुलीमा एक हजार बढीको आँखा तथा दन्त परीक्षण'
# - 'विद्यालय भवन हस्तान्तरण'
# - 'नेपालमा प्राकृतिक सौन्दर्य र सांस्कृतिक विविधता छ : मन्त्री पाण्डे'
# - 'वैदेशिक रोजगारीमा पठाइदिन्छु भन्दै ठगी गर्ने दुई जना पक्राउ'
# Initial number of rows: 120
# Number of duplicate titles found: 45
# Number of rows after cleaning: 75
# Number of rows removed: 45
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'इन्टरपोलबाट रेड नोटिस जारी भएका फरार व्यक्ति कतारबाट पक्राउ'
# - 'अमेरिका छिर्ने क्रममा पानामामा पक्राउ परेका २० नेपालीलाई काठमाडौं ल्याएर छाडियो'
# - 'करेन्ट लागेर युवकको मृत्यु'
# - 'अटोको ठक्करबाट बालकको मृत्यु, २ जना घाइते'
# - 'नेपालबाट प्रवेश गरेका शंकास्पद् चार चिनियाँलाई भारतीय प्रहरीले गर्यो पक्राउ'
# Initial number of rows: 99
# Number of duplicate titles found: 32
# Number of rows after cleaning: 67
# Number of rows removed: 32
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सुनसरी सीमाको सुरक्षामा कडाइ'
# - 'स्रोत नखुलेको करिब १५ लाख भारतीय रुपैयाँसहित एक जना पक्राउ'
# - 'भारतीय सेनाले भन्यो सीमापार गोलीबारीमा मृत्यु हुनेको संख्या १५ पुग्यो'
# - 'लोकतान्त्रिक गणतन्त्रलाई संस्थागत गर्न सबै एक भएर अगाडि बढ्नुपर्छ : मन्त्री सुडी'
# - 'दुई लाख घुससहित नवलपरासी अदालतका कर्मचारी पक्राउ'
# Initial number of rows: 109
# Number of duplicate titles found: 45
# Number of rows after cleaning: 64
# Number of rows removed: 45
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाले थप ७ नेपालीलाई गर्यो निष्कासन'
# - 'नेता नेपालको निधनप्रति प्रधानमन्त्रीद्वारा दुःख व्यक्त'
# - 'वातावरण संरक्षणमा प्रयास'
# - 'भारत भ्रमण निकै उपलब्धीमुलक : मुख्यमन्त्री शाह'
# - 'स्रोत नखुलेको रकमसहित दुई जना पक्राउ'
# Initial number of rows: 124
# Number of duplicate titles found: 48
# Number of rows after cleaning: 76
# Number of rows removed: 48
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'कोशीमा अपराधका ९ हजार बढी मुद्दा दर्ता'
# - 'मंगलबार देशका यी स्थानमा हुने छ वर्षा'
# - 'काठ र साइकल बरामद'
# - 'खोलामा डुबेर दुई जनाको मृत्यु'
# - 'जोखिम मोलेर काठको पुल तर्दै रिपवासी'
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'रुकुमपूर्वलाई हिमालय टुरिस्ट हब घोषणा'
# - 'बालेनले दिएको जिम्मेवारीमा बस्न तीन वडाध्यक्षद्वारा अस्वीकार'
# - '२० लाख रुपैयाँ बढी हुन्डीको रकमसहित युवक पक्राउ'
# - 'दक्षिण कोरियाले गर्यो १० नेपालीलाई निष्कासन'
# - 'सोमबार देशका यी स्थानमा हुने छ वर्षा'
# Initial number of rows: 92
# Number of duplicate titles found: 36
# Number of rows after cleaning: 56
# Number of rows removed: 36
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ ३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'प्रधानमन्त्री ओलीसँग जापानका उपविदेशमन्त्रीको शिष्टाचार भेट'
# - 'सवल शिक्षा'
# - 'कर्णालीको बुटी नै जडी'
# - 'यात्रुसँग मनपरी भाडा लिएको गुनासो आएपछि अनुगमन सुरु'
# - 'प्रधानमन्त्री ओली र कोप२९ का अध्यक्षबीच शिष्टाचार भेट, हिमालदेखि समुद्रसम्मको अवधारणामा छलफल'
# Initial number of rows: 111
# Number of duplicate titles found: 46
# Number of rows after cleaning: 65
# Number of rows removed: 46
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/जेठ २_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'स्वास्थ्य केन्द्रको भवन उद्घाटन'
# - 'सडक निर्माणका लागि घर भत्काउँदै गाउँपालिका'
# - 'विपद् न्यूनीकरण गर्न प्रहरीलाई तालिम'
# - 'मालिका पिस पार्क र मन्दिरको बारम्बार उद्घाटन'
# - 'भारतीय मन्त्री यादवले 'सगरमाथा संवाद'मा के भने?'
# ...
# Initial number of rows: 102
# Number of duplicate titles found: 43
# Number of rows after cleaning: 59
# Number of rows removed: 43
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख २_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - '१२ संघीय अस्पतालमा सेवा थप तथा विस्तार'
# - 'वीरगन्जमा फेरि तनाव, ठाउँठाउँमा टायर बालेर प्रदर्शन'
# - 'सरकार परिवर्तनबारे कांग्रेस नेताहरूसँग छलफल भइरहेको छ : प्रचण्ड'
# - 'सुतिरहेको अवस्थामा मजदुर मृत फेला'
# - 'झापामा मोटरसाइकलको ठक्करबाट पैदलयात्रीको मृत्यु'
# Initial number of rows: 68
# Number of duplicate titles found: 30
# Number of rows after cleaning: 38
# Number of rows removed: 30
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/वैशाख १_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'राष्ट्रपति रनिङ शिल्डको उपाधि विदुरलाई'
# - 'एमालेले भन्यो पूर्वराजाको अभिव्यक्ति आपत्तिजनक, आपराधिक क्रियाकलापलाई 'जनतामा आएको जागरण' भन्न सकिँदैन'
# - 'काठमाडौं उपत्यकासहित देशका विभिन्न स्थानमा वर्षा'
# - 'सिन्दूर हालेर मनाइयो सदियौं पुरानो सिन्दुरे जात्रा'
# - 'दक्षिण कोरियाले थप तीन नेपालीलाई गर्यो निष्कासन'
# Initial number of rows: 50
# Number of duplicate titles found: 6
# Number of rows after cleaning: 44
# Number of rows removed: 6
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अमेरिकाले फेरि गर्यो तीन नेपालीलाई निष्कासन'
# - 'डाक्टर पढाउने प्रदेशले डाक्टरकै सेवा पाउँदैन'
# - 'सिनामंगल हवाई इन्धन डिपो स्थानान्तरणको डीपीआर अन्तिम चरणमा'
# Initial number of rows: 67
# Number of duplicate titles found: 34
# Number of rows after cleaning: 33
# Number of rows removed: 34
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'कुलिङ पिरियड नराखि विधेयक अगाडि बढाउनु हुँदैन, संसदको अपमान गरी प्रावधान सच्याउनेलाई कारबाही गर्नुपर्छ'
# - 'कुलिङ पिरियडको छानबिन नभएसम्म एमाले, माओवादी र एसका सांसद सहभागी नहुने भएपश्चात राज्य व्यवस्था समितिको बैठक स्थगित'
# - 'कुलिङ पिरियडमा हेरफेर भएपछि समितिका सदस्यले भेटे सभामुख, भने  अपराध गर्नेलाई कारबाही हुनुपर्छ'
# - 'कांग्रेसले भन्यो कुलिङ पिरियडमा भएको छेडखानी क्षम्य हुँदैन'
# - 'कांग्रेस बैठकमा मन्त्रीहरूमाथि उठ्यो प्रश्न कार्यसम्पादन सन्तोषजनक नभएको गुनासो'
# Initial number of rows: 519
# Number of duplicate titles found: 483
# Number of rows after cleaning: 36
# Number of rows removed: 483
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १८_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'दाउन्नेको बेहाल, यात्रा कष्टकर'
# - 'राज्य व्यवस्था समितिमा एमाले, माओवादी र एकीकृत समाजवादीले मागे रामहरि खतिवडाको राजीनामा'
# - 'तिब्बतको उत्तराधिकारीबारे दलाई लामाको उद्घोष, चीन तरंगित'
# - ''डेटिङ एप' सञ्चालन गर्ने ६ चिनियाँसहित ५२ जना पक्राउ'
# - 'जापानले गर्यो चार नेपालीलाई निष्कासन'
# Initial number of rows: 0
# Number of duplicate titles found: 0
# Number of rows after cleaning: 0
# Number of rows removed: 0
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/_annupurna_post.csv
# Initial number of rows: 1798
# Number of duplicate titles found: 1765
# Number of rows after cleaning: 33
# Number of rows removed: 1765
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - '५२ संवैधानिक नियुक्ति सर्वोच्चद्वारा सदर : न्यायाधीशहरूबीच मत विभाजन, बहुमतद्वारा रिट खारेज'
# - 'दाउन्ने सडक खण्डको भाउन्न'
# - 'पूर्वराष्ट्रपति भण्डारीद्वारा सरकारी सेवासुविधा त्याग'
# - 'वैभव सूर्यवंशीले इङ्गल्याण्डमा मच्चाए धमाका, बनाए कीर्तिमानी रेकर्ड'
# - 'जब लाग्यो असार, विकास खर्चमा हतार'
# Initial number of rows: 1667
# Number of duplicate titles found: 1634
# Number of rows after cleaning: 33
# Number of rows removed: 1634
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'संघीय निजामती सेवा विधेयक : बढुवासम्बन्धी व्यवस्थामा पनि छलछाम'
# - 'रुसबाट तेल खरिद गरेमा भारतमाथि ५०० प्रतिशत कर लगाउने अमेरिकाको तयारी'
# - 'अब नियुक्त हुने सरकारी कर्मचारीलाई पेन्सन र उपदानको सट्टा योगदानमा आधारित सामाजिक सुरक्षा'
# - 'राजर्षि जनक विश्वविद्यालय : न देशले हेर्छ, न प्रदेशले'
# - 'युक्रेनमाथि हालसम्मकै ठूलो रूसी आक्रमण'
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार १९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - '५२ संवैधानिक नियुक्ति सर्वोच्चद्वारा सदर : न्यायाधीशहरूबीच मत विभाजन, बहुमतद्वारा रिट खारेज'
# - 'दाउन्ने सडक खण्डको भाउन्न'
# - 'पूर्वराष्ट्रपति भण्डारीद्वारा सरकारी सेवासुविधा त्याग'
# - 'वैभव सूर्यवंशीले इङ्गल्याण्डमा मच्चाए धमाका, बनाए कीर्तिमानी रेकर्ड'
# - 'जब लाग्यो असार, विकास खर्चमा हतार'
# Initial number of rows: 1667
# Number of duplicate titles found: 1634
# Number of rows after cleaning: 33
# Number of rows removed: 1634
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'संघीय निजामती सेवा विधेयक : बढुवासम्बन्धी व्यवस्थामा पनि छलछाम'
# - 'रुसबाट तेल खरिद गरेमा भारतमाथि ५०० प्रतिशत कर लगाउने अमेरिकाको तयारी'
# - 'अब नियुक्त हुने सरकारी कर्मचारीलाई पेन्सन र उपदानको सट्टा योगदानमा आधारित सामाजिक सुरक्षा'
# - 'राजर्षि जनक विश्वविद्यालय : न देशले हेर्छ, न प्रदेशले'
# - 'युक्रेनमाथि हालसम्मकै ठूलो रूसी आक्रमण'
# Initial number of rows: 2461
# Number of duplicate titles found: 2435
# Number of rows after cleaning: 26
# Number of rows removed: 2435
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'रेनकोट ओढेर मध्यरातमा सडक कालोपत्रे'
# - 'नेपालले आज उज्बेकिस्तानसँग खेल्दै, इतिहास रच्ने अवसर'
# - 'नेपालले उचाल्यो एसीसी यू१६ इस्ट जोन कपको उपाधि'
# - 'हर्क साम्पाङको श्रमदानमा सहभागी भएका धरान ४ का वडाध्यक्षलाई बर्खास्त गर्न एमालेको सिफारिस'
# - 'प्रतिस्पर्धाबिना सेटिङमा नै १ रुपैयाँको फरकमा ३ बोलपत्र'
# Initial number of rows: 2876
# Number of duplicate titles found: 2848
# Number of rows after cleaning: 28
# Number of rows removed: 2848
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भोजपुरमा श्रीमतीसहित चार जनाको सामूहिक हत्या, हत्यारा पनि गम्भीर घाइते'
# - '३५ दिनमै बन्यो बेलिब्रिज, उद्घाटन गर्न प्रधानमन्त्री ओली आज हुम्ला आउँदै'
# - 'ट्रम्पलाई टक्कर दिन एलन मस्कले खोले नयाँ पार्टी'
# - 'ताजियाको सुरक्षामा खटिएका सुरक्षाकर्मीलाई नै किच्ने गरी गाडी चलाउनेलाई कारबाही हुन्छ : एसपी मिश्र'
# - 'डिभिजन बन प्रमुखमाथि भ्रष्टाचार गरेको भन्दै कार्यकक्षमै कुटपिट'
# Initial number of rows: 2835
# Number of duplicate titles found: 2788
# Number of rows after cleaning: 47
# Number of rows removed: 2788
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अब गाडीमा सरर हुम्ला सिमकोट'
# - 'नयाँ पार्टी गठनको घोषणा गरेपछि ट्रम्पले बनाए मस्कमाथि निशाना'
# - 'प्रधानमन्त्री ओली र नाउपा संरक्षक रेशम चौधरीबीच बालुवाटारमा भेटवार्ता'
# - 'राम नेपाली भूमिमा जन्मिएका हुन्, प्रचार गर्न नडराऔं : प्रधानमन्त्री ओली'
# - 'आज राति देशका यी स्थानमा हुने छ भारी वर्षा'
# Initial number of rows: 2461
# Number of duplicate titles found: 2435
# Number of rows after cleaning: 26
# Number of rows removed: 2435
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २१_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'रेनकोट ओढेर मध्यरातमा सडक कालोपत्रे'
# - 'नेपालले आज उज्बेकिस्तानसँग खेल्दै, इतिहास रच्ने अवसर'
# - 'नेपालले उचाल्यो एसीसी यू१६ इस्ट जोन कपको उपाधि'
# - 'हर्क साम्पाङको श्रमदानमा सहभागी भएका धरान ४ का वडाध्यक्षलाई बर्खास्त गर्न एमालेको सिफारिस'
# - 'प्रतिस्पर्धाबिना सेटिङमा नै १ रुपैयाँको फरकमा ३ बोलपत्र'
# Initial number of rows: 2876
# Number of duplicate titles found: 2848
# Number of rows after cleaning: 28
# Number of rows removed: 2848
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २२_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'भोजपुरमा श्रीमतीसहित चार जनाको सामूहिक हत्या, हत्यारा पनि गम्भीर घाइते'
# - '३५ दिनमै बन्यो बेलिब्रिज, उद्घाटन गर्न प्रधानमन्त्री ओली आज हुम्ला आउँदै'
# - 'ट्रम्पलाई टक्कर दिन एलन मस्कले खोले नयाँ पार्टी'
# - 'ताजियाको सुरक्षामा खटिएका सुरक्षाकर्मीलाई नै किच्ने गरी गाडी चलाउनेलाई कारबाही हुन्छ : एसपी मिश्र'
# - 'डिभिजन बन प्रमुखमाथि भ्रष्टाचार गरेको भन्दै कार्यकक्षमै कुटपिट'
# Initial number of rows: 2835
# Number of duplicate titles found: 2788
# Number of rows after cleaning: 47
# Number of rows removed: 2788
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २३_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अब गाडीमा सरर हुम्ला सिमकोट'
# - 'नयाँ पार्टी गठनको घोषणा गरेपछि ट्रम्पले बनाए मस्कमाथि निशाना'
# - 'प्रधानमन्त्री ओली र नाउपा संरक्षक रेशम चौधरीबीच बालुवाटारमा भेटवार्ता'
# - 'राम नेपाली भूमिमा जन्मिएका हुन्, प्रचार गर्न नडराऔं : प्रधानमन्त्री ओली'
# - 'आज राति देशका यी स्थानमा हुने छ भारी वर्षा'
# Initial number of rows: 3380
# Number of duplicate titles found: 3335
# Number of rows after cleaning: 45
# Number of rows removed: 3335
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'बाढीले रसुवागढी नाका जोड्ने पक्की पुल र सवारी साधन बगायो'
# - 'त्रिशुलीको बाढीमा फसेका दुई जनाको सेनाको हेलिकोप्टरमार्फत उद्धार'
# - 'भोटेकोशीको बाढीमा फसेका प्रहरीसहित सबैको पहिचान खुल्यो'
# - 'अंश विवाद बढ्दै जाँदा देवरले गरे भाउजूको हत्या'
# - 'मधेस प्रदेशको बजेटमा बिचौलिया'
# Initial number of rows: 2429
# Number of duplicate titles found: 2421
# Number of rows after cleaning: 8
# Number of rows removed: 2421
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'श्रीमान अर्कै युवतीको कोठामा गएको चाल पाएपछि साथी भेला गराइ कुटपिट, एकको मृत्यु, छजना पक्राउ'
# - 'लाल सागरमा कार्गो जहाजमाथि आक्रमण, चालक दलका दुईजनाको मृत्यु'
# - 'बेलायतमा मृत्यु भएका दुई नेपाली विद्यार्थीको लन्डनमा अन्त्येष्टि, नेपालमा रहेका परिवारले भिडियोबाटै हेरे'
# - 'एमालेले नफर्कनेको नामावली मागेपछि सोविता गौतमको स्पष्टीकरण : प्रधानमन्त्रीसँगै स्पेन गएका भनेको छैन'
# - 'भिसामा कैफियत देखिएपछि क्रोएसिया पुगेका ११ नेपालीलाई विमानस्थलबाटै फर्काइयो'
# Initial number of rows: 3380
# Number of duplicate titles found: 3335
# Number of rows after cleaning: 45
# Number of rows removed: 3335
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २४_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'बाढीले रसुवागढी नाका जोड्ने पक्की पुल र सवारी साधन बगायो'
# - 'त्रिशुलीको बाढीमा फसेका दुई जनाको सेनाको हेलिकोप्टरमार्फत उद्धार'
# - 'भोटेकोशीको बाढीमा फसेका प्रहरीसहित सबैको पहिचान खुल्यो'
# - 'अंश विवाद बढ्दै जाँदा देवरले गरे भाउजूको हत्या'
# - 'मधेस प्रदेशको बजेटमा बिचौलिया'
# Initial number of rows: 2429
# Number of duplicate titles found: 2421
# Number of rows after cleaning: 8
# Number of rows removed: 2421
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २५_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'श्रीमान अर्कै युवतीको कोठामा गएको चाल पाएपछि साथी भेला गराइ कुटपिट, एकको मृत्यु, छजना पक्राउ'
# - 'लाल सागरमा कार्गो जहाजमाथि आक्रमण, चालक दलका दुईजनाको मृत्यु'
# - 'बेलायतमा मृत्यु भएका दुई नेपाली विद्यार्थीको लन्डनमा अन्त्येष्टि, नेपालमा रहेका परिवारले भिडियोबाटै हेरे'
# - 'एमालेले नफर्कनेको नामावली मागेपछि सोविता गौतमको स्पष्टीकरण : प्रधानमन्त्रीसँगै स्पेन गएका भनेको छैन'
# - 'भिसामा कैफियत देखिएपछि क्रोएसिया पुगेका ११ नेपालीलाई विमानस्थलबाटै फर्काइयो'
# Initial number of rows: 1686
# Number of duplicate titles found: 1680
# Number of rows after cleaning: 6
# Number of rows removed: 1680
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'टी२० विश्वकप छनोट : नेपाल समूह बीमा'
# - 'खेलकुदमन्त्रीलाई प्रधानमन्त्रीको चेतावनी खेलकुद राजनीति गर्ने ठाउँ होइन, एनपीएल अगाडि बढ्छ'
# - 'अनुशासन उलंघन गरेको भन्दै कांग्रेसले गर्यो कारबाही, असन्तुष्ट जनाउँदै शेखर कोइराला समूहले बोलायो बैठक'
# - 'आधा दर्जन बढी जलविद्युत् आयोजना प्रभावित, २५० मेगावाट बन्द'
# - 'संसद् भवनमा ड्रोन खसालेको आरोपमा पाँच जना नियन्त्रणमा'
# Initial number of rows: 1769
# Number of duplicate titles found: 1757
# Number of rows after cleaning: 12
# Number of rows removed: 1757
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सर्वोच्च अदालतको आदेशप्रति पूर्वन्यायाधीशको टिप्पणी : न्यायपालिकामा राजनीतिको छाया पर्यो'
# - 'क्यानडामा कपिल शर्माको क्याफेमा गोलीबारी, खालिस्तानी आतंककारीले लिए जिम्मेवारी'
# - 'क्यानडामा कपिल शर्माको क्याफेमा गोलीबारी, खालिस्तानीले लिए जिम्मेवारी'
# - 'पाकिस्तानमा बसबाट निकालेर ९ जना यात्रुलाई गोली हानी हत्या'
# - 'एक मिनेटमै सक्यो काठमाडौं महानगरको कार्यपालिका बैठक, बजेट आइतबार आउने'
# Initial number of rows: 19
# Number of duplicate titles found: 0
# Number of rows after cleaning: 19
# Number of rows removed: 0
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २८_annupurna_post.csv
# Initial number of rows: 736
# Number of duplicate titles found: 705
# Number of rows after cleaning: 31
# Number of rows removed: 705
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अनि, आलम सफाइविरुद्ध सरकार जाने भयो पुनरावेदन'
# - 'पूर्वराष्ट्रपति भण्डारीसँगको भेटबारे माओवादीका वरिष्ठ उपाध्यक्ष श्रेष्ठले भने : प्रचण्डले पनि पार्टीमा निर्णय गराएर भेट्दैनन्'
# - ''ह्याप्पी बर्थ डे मेरी जान' भन्दै छात्राको जन्मदिनमा शिक्षकले शुभकामना पठाएपछि'
# - 'क्यान्सरका बिरामीलाई दुर्लभ महंगो औषधि निःशुल्क, चार अस्पतालबाट सेवा लिन सकिने'
# - 'मिथिला मरुभूमितिर'
# Initial number of rows: 481
# Number of duplicate titles found: 466
# Number of rows after cleaning: 15
# Number of rows removed: 466
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ३०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आफ्नै कमाइले पक्कीघर बनाइन्, छाउगोठमा बस्दा ज्यान गुमाइन्'
# - 'लन्डन साउथेन्ड विमानस्थलमा उड्नेबित्तिकै खस्यो विमान, आगलागी भएपछि विमानस्थल बन्द'
# - 'इजरायली आक्रमणमा इरानी राष्ट्रपति घाइते'
# - 'फिफा क्लब विश्वकपको फाइनलमा पीएसजी र चेल्सीका खेलाडीबीच झगडा'
# Initial number of rows: 1686
# Number of duplicate titles found: 1680
# Number of rows after cleaning: 6
# Number of rows removed: 1680
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २६_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'टी२० विश्वकप छनोट : नेपाल समूह बीमा'
# - 'खेलकुदमन्त्रीलाई प्रधानमन्त्रीको चेतावनी खेलकुद राजनीति गर्ने ठाउँ होइन, एनपीएल अगाडि बढ्छ'
# - 'अनुशासन उलंघन गरेको भन्दै कांग्रेसले गर्यो कारबाही, असन्तुष्ट जनाउँदै शेखर कोइराला समूहले बोलायो बैठक'
# - 'आधा दर्जन बढी जलविद्युत् आयोजना प्रभावित, २५० मेगावाट बन्द'
# - 'संसद् भवनमा ड्रोन खसालेको आरोपमा पाँच जना नियन्त्रणमा'
# Initial number of rows: 1769
# Number of duplicate titles found: 1757
# Number of rows after cleaning: 12
# Number of rows removed: 1757
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २७_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'सर्वोच्च अदालतको आदेशप्रति पूर्वन्यायाधीशको टिप्पणी : न्यायपालिकामा राजनीतिको छाया पर्यो'
# - 'क्यानडामा कपिल शर्माको क्याफेमा गोलीबारी, खालिस्तानी आतंककारीले लिए जिम्मेवारी'
# - 'क्यानडामा कपिल शर्माको क्याफेमा गोलीबारी, खालिस्तानीले लिए जिम्मेवारी'
# - 'पाकिस्तानमा बसबाट निकालेर ९ जना यात्रुलाई गोली हानी हत्या'
# - 'एक मिनेटमै सक्यो काठमाडौं महानगरको कार्यपालिका बैठक, बजेट आइतबार आउने'
# Initial number of rows: 19
# Number of duplicate titles found: 0
# Number of rows after cleaning: 19
# Number of rows removed: 0
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २८_annupurna_post.csv
# Initial number of rows: 736
# Number of duplicate titles found: 705
# Number of rows after cleaning: 31
# Number of rows removed: 705
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार २९_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'अनि, आलम सफाइविरुद्ध सरकार जाने भयो पुनरावेदन'
# - 'पूर्वराष्ट्रपति भण्डारीसँगको भेटबारे माओवादीका वरिष्ठ उपाध्यक्ष श्रेष्ठले भने : प्रचण्डले पनि पार्टीमा निर्णय गराएर भेट्दैनन्'
# - ''ह्याप्पी बर्थ डे मेरी जान' भन्दै छात्राको जन्मदिनमा शिक्षकले शुभकामना पठाएपछि'
# - 'क्यान्सरका बिरामीलाई दुर्लभ महंगो औषधि निःशुल्क, चार अस्पतालबाट सेवा लिन सकिने'
# - 'मिथिला मरुभूमितिर'
# Initial number of rows: 481
# Number of duplicate titles found: 466
# Number of rows after cleaning: 15
# Number of rows removed: 466
# Cleaned data saved to: News_csv/AnnapurnaPost/२०८२/असार ३०_annupurna_post.csv
#
# Examples of removed duplicate titles:
# - 'आफ्नै कमाइले पक्कीघर बनाइन्, छाउगोठमा बस्दा ज्यान गुमाइन्'
# - 'लन्डन साउथेन्ड विमानस्थलमा उड्नेबित्तिकै खस्यो विमान, आगलागी भएपछि विमानस्थल बन्द'
# - 'इजरायली आक्रमणमा इरानी राष्ट्रपति घाइते'
# - 'फिफा क्लब विश्वकपको फाइनलमा पीएसजी र चेल्सीका खेलाडीबीच झगडा'

# %%
# Different ways to get files from a folder in Python

import os
import glob
from pathlib import Path

# Method 1: Using os.listdir() - gets all items in directory
def get_files_with_listdir(folder_path):
    """Get all files using os.listdir()"""
    try:
        items = os.listdir(folder_path)
        # Filter only files (not directories)
        files = [item for item in items if os.path.isfile(os.path.join(folder_path, item))]
        return files
    except FileNotFoundError:
        print(f"Folder '{folder_path}' not found")
        return []

# Method 2: Using os.walk() - recursive through subdirectories
def get_files_with_walk(folder_path):
    """Get all files recursively using os.walk()"""
    files = []
    for root, dirs, file_list in os.walk(folder_path):
        for file in file_list:
            files.append(os.path.join(root, file))
    return files

# Method 3: Using glob - pattern matching
def get_files_with_glob(folder_path, pattern="*"):
    """Get files using glob with pattern matching"""
    search_pattern = os.path.join(folder_path, pattern)
    return glob.glob(search_pattern)

# Method 4: Using pathlib (modern Python approach)
def get_files_with_pathlib(folder_path):
    """Get files using pathlib - modern Python way"""
    folder = Path(folder_path)
    if folder.exists():
        return [file for file in folder.iterdir() if file.is_file()]
    else:
        print(f"Folder '{folder_path}' not found")
        return []

# Method 5: Get files with specific extensions
def get_files_by_extension(folder_path, extensions):
    """Get files with specific extensions"""
    files = []
    if isinstance(extensions, str):
        extensions = [extensions]
    
    for file in os.listdir(folder_path):
        if any(file.endswith(ext) for ext in extensions):
            files.append(os.path.join(folder_path, file))
    return files

# Examples
print("=== Example Usage ===")

# Example folder path
folder_path = "News_csv"

print(f"Getting files from: {folder_path}")
print()

# Method 1: os.listdir()
print("1. Using os.listdir():")
files = get_files_with_listdir(folder_path)
for file in files[:5]:  # Show first 5 files
    print(f"   {file}")
if len(files) > 5:
    print(f"   ... and {len(files) - 5} more files")
print()

# Method 2: os.walk() - recursive
print("2. Using os.walk() (recursive):")
all_files = get_files_with_walk(folder_path)
for file in all_files[:5]:  # Show first 5 files
    print(f"   {file}")
if len(all_files) > 5:
    print(f"   ... and {len(all_files) - 5} more files")
print()

# Method 3: glob with pattern
print("3. Using glob for CSV files:")
csv_files = get_files_with_glob(folder_path, "*.csv")
for file in csv_files[:5]:
    print(f"   {file}")
if len(csv_files) > 5:
    print(f"   ... and {len(csv_files) - 5} more files")
print()

# Method 4: pathlib
print("4. Using pathlib:")
path_files = get_files_with_pathlib(folder_path)
for file in path_files[:5]:
    print(f"   {file}")
if len(path_files) > 5:
    print(f"   ... and {len(path_files) - 5} more files")
print()

# Method 5: Specific extensions
print("5. Getting only .csv and .txt files:")
specific_files = get_files_by_extension(folder_path, ['.csv', '.txt'])
for file in specific_files[:5]:
    print(f"   {file}")
if len(specific_files) > 5:
    print(f"   ... and {len(specific_files) - 5} more files")
# Out:
# === Example Usage ===
# Getting files from: News_csv
#
# 1. Using os.listdir():
#
# 2. Using os.walk() (recursive):
#    News_csv/eKantipur/2025-06-02_ekantipur_news.csv
#    News_csv/eKantipur/2025-06-09_ekantipur_news.csv
#    News_csv/eKantipur/2025-06-03_ekantipur_news.csv
#    News_csv/eKantipur/2025-06-04_ekantipur_news.csv
#    News_csv/eKantipur/2025-06-05_ekantipur_news.csv
#    ... and 6231 more files
#
# 3. Using glob for CSV files:
#
# 4. Using pathlib:
#
# 5. Getting only .csv and .txt files:

# %%
# More practical examples

print("=== PRACTICAL EXAMPLES ===")
print()

# Example 1: Get all CSV files recursively
print("1. All CSV files in News_csv directory:")
csv_files = []
for root, dirs, files in os.walk("News_csv"):
    for file in files:
        if file.endswith('.csv'):
            csv_files.append(os.path.join(root, file))

print(f"Found {len(csv_files)} CSV files")
for file in csv_files[:5]:
    print(f"   {file}")
if len(csv_files) > 5:
    print(f"   ... and {len(csv_files) - 5} more")
print()

# Example 2: Get files with size information
print("2. Files with size information:")
folder = "News_csv/eKantipur"
if os.path.exists(folder):
    files_with_size = []
    for file in os.listdir(folder):
        file_path = os.path.join(folder, file)
        if os.path.isfile(file_path):
            size = os.path.getsize(file_path)
            files_with_size.append((file, size))
    
    # Sort by size (largest first)
    files_with_size.sort(key=lambda x: x[1], reverse=True)
    
    for file, size in files_with_size[:5]:
        print(f"   {file}: {size:,} bytes")
    print()

# Example 3: Filter files by date in filename
print("3. Files from June 2025:")
june_files = []
for file in csv_files:
    if "2025-06" in file:
        june_files.append(file)

print(f"Found {len(june_files)} files from June 2025")
for file in june_files[:3]:
    print(f"   {os.path.basename(file)}")
print()

# Example 4: Using pathlib for modern approach
print("4. Using pathlib (recommended for new code):")
from pathlib import Path

news_path = Path("News_csv")
if news_path.exists():
    # Get all .csv files recursively
    csv_files_pathlib = list(news_path.rglob("*.csv"))
    print(f"Found {len(csv_files_pathlib)} CSV files using pathlib")
    
    # Get files from specific subfolder
    ekantipur_path = news_path / "eKantipur"
    if ekantipur_path.exists():
        ekantipur_files = list(ekantipur_path.glob("*.csv"))
        print(f"Found {len(ekantipur_files)} files in eKantipur folder")
        for file in ekantipur_files[:3]:
            print(f"   {file.name}")
print()

# Example 5: Get files modified in last N days
print("5. Recently modified files:")
import time
from datetime import datetime, timedelta

def get_recent_files(folder, days=7):
    """Get files modified in the last N days"""
    recent_files = []
    cutoff_time = time.time() - (days * 24 * 60 * 60)
    
    for root, dirs, files in os.walk(folder):
        for file in files:
            file_path = os.path.join(root, file)
            if os.path.getmtime(file_path) > cutoff_time:
                recent_files.append(file_path)
    
    return recent_files

recent = get_recent_files("News_csv", days=30)
print(f"Files modified in last 30 days: {len(recent)}")
for file in recent[:3]:
    mod_time = os.path.getmtime(file)
    mod_date = datetime.fromtimestamp(mod_time).strftime("%Y-%m-%d %H:%M")
    print(f"   {os.path.basename(file)} (modified: {mod_date})")

# %% [markdown]
# # Summary: Getting Files from Folders in Python
#
# ## Quick Reference
#
# ### 1. **os.listdir()** - Simple file listing
# ```python
# import os
# files = os.listdir("folder_path")
# # Returns: ['file1.txt', 'file2.csv', 'subfolder']
# ```
#
# ### 2. **os.walk()** - Recursive directory traversal
# ```python
# for root, dirs, files in os.walk("folder_path"):
#     for file in files:
#         full_path = os.path.join(root, file)
# ```
#
# ### 3. **glob** - Pattern matching
# ```python
# import glob
# csv_files = glob.glob("folder_path/*.csv")  # All CSV files
# all_files = glob.glob("folder_path/**", recursive=True)  # Recursive
# ```
#
# ### 4. **pathlib** - Modern Python approach (Recommended)
# ```python
# from pathlib import Path
# folder = Path("folder_path")
# files = [f for f in folder.iterdir() if f.is_file()]  # Files only
# csv_files = list(folder.glob("*.csv"))  # CSV files only
# all_csv = list(folder.rglob("*.csv"))  # Recursive CSV search
# ```
#
# ## When to Use Each Method:
#
# - **os.listdir()**: Simple, single directory, when you need just filenames
# - **os.walk()**: When you need recursive search with full control
# - **glob**: When you need pattern matching (wildcards)
# - **pathlib**: Modern, object-oriented approach (recommended for new code)
#
# ## Common Patterns:
#
# ```python
# # Get only files (not directories)
# files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
#
# # Get files with specific extensions
# csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
#
# # Get full file paths
# full_paths = [os.path.join(path, f) for f in os.listdir(path)]
# ```
